# %% [markdown]
# # Ingredients Model
#
# This Notebook shows the process of clustering of the users according to the ingredients they use in their recipes.
#
# It links each users with all the recipes he/she has made, then forms list of all ingredients contained in thoses recipes and computes a User/Ingredient relevance matrix using a TF-IDF approach.
#
# The users are then projected on a 2D space by performing a Non-Negative Matrix Factorization of the Normalized User/Recipe relevance matrix followed by a t-SNE.
#
# The users are then clustered using DBSCAN.
#
# For the main clusters, a specificity score is computed for each ingredients. The specificity scores represents how relevant the ingredient is for a specific cluster.
#
# Using the specificity scores of the ingredients/clusters, a similarity score is computed between the recipes and the clusters, allowing to obtain a ranked list of most similar recipes for each clusters.

# %%
import os
import json
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd 
import numpy as np
import pylab as pl
from scipy.sparse import lil_matrix
from util import *
# %matplotlib inline

# %% [markdown]
# ## Load recipes data

# %%
recipes = [f.path.split("/")[1] for f in os.scandir("recipe_data/") if f.is_dir() ]    
print(recipes[:10])
print("Nb of recipes: " + str(len(recipes)))
# Out:
# ['229804', '245348', '25093', '14930', '257743', '255991', '236394', '13148', '18454', '215435']
# Nb of recipes: 44069

# %%
recipesDict = {}
for recipe in recipes:
    recipesDict[recipe] = True

# %%
recipesLinks = pd.read_csv("indexes/links.csv")
recipesNames = recipesLinks["Recipe title"]
recipesID = recipesLinks["Recipe link"].map(lambda x: x.split("/")[2])
recipesIDNames = {}

for i in range(len(recipesLinks)):
    recipesIDNames[recipesID[i]] = recipesNames[i]

# %% [markdown]
# ## Load users data and filter user with 10+ recipes only

# %%
with open("data/user_data.json", "r") as in_file:
    users_data = json.load(in_file)

# %%
len(users_data.keys())
# Out:
# 1017178

# %%
for user in users_data.keys():
    users_data[user]["made"] = list(filter(lambda x: str(x) in recipesDict, users_data[user]["made"]))

# %%
users_data = {k: v for k, v in users_data.items() if len(v["made"]) > 30 and len(v["made"]) < 200}
users = list(users_data.keys())

# %%
len(users_data.keys())
# Out:
# 16758

# %% [markdown]
# ## Link recipes and ingredients

# %%
def getIngredientList(recipe):
    with open("recipe_data/" + recipe + "/data.json", "r") as input_file:
        data = json.load(input_file)
    return data["ingredients"]

# %%
recipeIngredients = {}
for recipe in recipes:
    recipeIngredients[recipe] = getIngredientList(recipe)

# %%
ingredientIDText = {}

for recipe in recipes:
    for ingredient in recipeIngredients[recipe]:
        if ingredient["id"] not in ingredientIDText:
            ingredientIDText[ingredient["id"]] = ingredient["text"]

# %%
len(ingredientIDText.items())
# Out:
# 6479

# %%
len(ingredientIDText.keys())
# Out:
# 6479

# %%
ingredientIdx, ingredientUnique = pd.factorize(list(ingredientIDText.keys()))
ingredientDict = {}
for i in range(len(ingredientUnique)):
    if ingredientUnique[i] in ingredientDict:
        print("Problem with " + str(ingredientUnique[i]))
    else:
        ingredientDict[ingredientUnique[i]] = i

# %%
userIdx, userUnique = pd.factorize(users)

# %% [markdown]
# # TF/IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def getUsersIngredients(recipes):
    ingredients = []
    for recipe in recipes:
        for ingredient in recipeIngredients[str(recipe)]:
            ingredients.append(ingredient["id"])
    return " ".join(ingredients)

# %%
usersDF = pd.DataFrame(users)
usersDF.columns = ["user"]
usersDF["recipes"] = usersDF["user"].map(lambda x: users_data[x]["made"])
usersDF["ingredients"] = usersDF["recipes"].map(lambda x: getUsersIngredients(x))

# %%
usersDF.head()
# Out:
#       user                                            recipes  \
# 0   973722  [8854, 77981, 61024, 23567, 8758, 26317, 16198...
# 1  1312442  [8941, 8665, 11864, 139340, 80285, 11843, 1419...
# 2   269580  [77981, 12072, 67952, 54675, 21766, 141678, 58...
# 3  3715648  [142434, 221239, 12942, 176287, 25112, 11458, ...
# 4  1168774  [6737, 69384, 23094, 70749, 42719, 9615, 7458,...
#
#                                          ingredients
# 0  4252 6549 615 16278 16215 16157 2112 16157 439...
# 1  6494 16157 5467 4397 2061 6494 18740 16406 630...
# 2  16157 4397 4292 4279 4442 4537 16133 16421 176...
# 3  4808 16278 1525 16386 10643 3717 2882 16396 51...
# 4  2362 1525 16421 2496 1684 1686 2496 2359 16157...

# %%
vectorizer = TfidfVectorizer(max_df=0.5, min_df=5)
X = vectorizer.fit_transform(usersDF["ingredients"])
X.shape
# Out:
# (16758, 3474)

# %%
ingredientsMap = vectorizer.get_feature_names()    
reverseIngredientsMap = {}
for i in range(len(ingredientsMap)):
    reverseIngredientsMap[ingredientsMap[i]] = i

# %%
Xraw = X

# %% [markdown]
# ## Clustering

# %%
from sklearn.decomposition import NMF
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from sklearn import preprocessing

X_normalized = Xraw
X_normalized = preprocessing.normalize(X_normalized,'l1')
X_normalized.shape

model = NMF(n_components=10, init='random',random_state=0)
W = model.fit_transform(X_normalized)
H = model.components_

digits_proj = TSNE(n_components=2, verbose=2).fit_transform(W)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 16758 samples in 0.015s...
# [t-SNE] Computed neighbors for 16758 samples in 5.863s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 16758
# [t-SNE] Computed conditional probabilities for sample 2000 / 16758
# [t-SNE] Computed conditional probabilities for sample 3000 / 16758
# [t-SNE] Computed conditional probabilities for sample 4000 / 16758
# [t-SNE] Computed conditional probabilities for sample 5000 / 16758
# [t-SNE] Computed conditional probabilities for sample 6000 / 16758
# [t-SNE] Computed conditional probabilities for sample 7000 / 16758
# [t-SNE] Computed conditional probabilities for sample 8000 / 16758
# [t-SNE] Computed conditional probabilities for sample 9000 / 16758
# [t-SNE] Computed conditional probabilities for sample 10000 / 16758
# [t-SNE] Computed conditional probabilities for sample 11000 / 16758
# [t-SNE] Computed conditional probabilities for sample 12000 / 16758
# [t-SNE] Computed conditional probabilities for sample 13000 / 16758
# [t-SNE] Computed conditional probabilities for sample 14000 / 16758
# [t-SNE] Computed conditional probabilities for sample 15000 / 16758
# [t-SNE] Computed conditional probabilities for sample 16000 / 16758
# [t-SNE] Computed conditional probabilities for sample 16758 / 16758
# [t-SNE] Mean sigma: 0.006654
# [t-SNE] Computed conditional probabilities in 2.070s
# [t-SNE] Iteration 50: error = 103.6293259, gradient norm = 0.0000207 (50 iterations in 32.705s)
# [t-SNE] Iteration 100: error = 98.7958527, gradient norm = 0.0011461 (50 iterations in 48.542s)
# [t-SNE] Iteration 150: error = 98.3229446, gradient norm = 0.0000152 (50 iterations in 28.923s)
# [t-SNE] Iteration 200: error = 98.3224182, gradient norm = 0.0000018 (50 iterations in 27.289s)
# [t-SNE] Iteration 250: error = 98.3224411, gradient norm = 0.0000018 (50 iterations in 26.513s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 98.322441
# [t-SNE] Iteration 300: error = 4.0914602, gradient norm = 0.0011176 (50 iterations in 25.640s)
# [t-SNE] Iteration 350: error = 3.6433067, gradient norm = 0.0005821 (50 iterations in 23.087s)
# [t-SNE] Iteration 400: error = 3.3999908, gradient norm = 0.0003727 (50 iterations in 24.191s)
# [t-SNE] Iteration 450: error = 3.2445736, gradient norm = 0.0002635 (50 iterations in 24.564s)
# [t-SNE] Iteration 500: error = 3.1335015, gradient norm = 0.0001979 (50 iterations in 23.887s)
# [t-SNE] Iteration 550: error = 3.0501695, gradient norm = 0.0001563 (50 iterations in 25.768s)
# [t-SNE] Iteration 600: error = 2.9858601, gradient norm = 0.0001280 (50 iterations in 30.458s)
# [t-SNE] Iteration 650: error = 2.9340310, gradient norm = 0.0001095 (50 iterations in 24.388s)
# [t-SNE] Iteration 700: error = 2.8913593, gradient norm = 0.0000953 (50 iterations in 26.814s)
# [t-SNE] Iteration 750: error = 2.8563738, gradient norm = 0.0000815 (50 iterations in 25.248s)
# [t-SNE] Iteration 800: error = 2.8267920, gradient norm = 0.0000713 (50 iterations in 24.863s)
# [t-SNE] Iteration 850: error = 2.8016579, gradient norm = 0.0000633 (50 iterations in 23.487s)
# [t-SNE] Iteration 900: error = 2.7799671, gradient norm = 0.0000568 (50 iterations in 25.363s)
# [t-SNE] Iteration 950: error = 2.7613487, gradient norm = 0.0000512 (50 iterations in 23.360s)
# [t-SNE] Iteration 1000: error = 2.7453570, gradient norm = 0.0000473 (50 iterations in 24.308s)
# [t-SNE] Error after 1000 iterations: 2.745357

# %%
# plotting
def set_colors(labels, colors=None):
    import random
    r = lambda: random.randint(30,255)
    if colors is None:
        colors = 'mrgybc'*1000 + "k"
        colors = []
        for i in range(len(labels)-1):
            colors.append('#%02X%02X%02X' % (r(),r(),r()))
        colors.append('#000000')
    colored_labels = []
    for label in labels:
        colored_labels.append(colors[label])
    return colored_labels

# Fit a DBSCAN estimator
estimator = DBSCAN(eps=1.3, min_samples=5)
estimator.fit(digits_proj)
# Clusters are given in the labels_ attribute
labels = estimator.labels_

colors = set_colors(labels)
fig = plt.gcf()
fig.set_size_inches(14, 8)
ax = plt.scatter(digits_proj[:,0], digits_proj[:,1], lw=0, s=20, c=colors)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Users 2D Projection")
plt.show()

# %%
from collections import Counter
feat_names = np.array(vectorizer.get_feature_names())
label_cnt = Counter(labels)

# %%
label_cnt[1] = 0
filtered_labels = list(filter(lambda x: x[0] != -1, label_cnt.most_common()))
filtered_labels = filtered_labels[0:10]
filtered_labels
# Out:
# [(0, 514),
#  (72, 488),
#  (6, 424),
#  (26, 420),
#  (2, 290),
#  (132, 267),
#  (17, 259),
#  (66, 259),
#  (101, 215),
#  (22, 209)]

# %% [markdown]
# ## Computing ingredients specificity
#
# the specificity score $ S_{ci} $ of ingredient $i$ for cluster $c$ is computed as follow:
#
# $$ S_{ci} = p_{ci} - p_{ji} $$
#
# where:
# * $ p_{ci} $ is the frequency of ingredient $i$ in cluster $c$
# * $ p_{ji} $ is the frequency of ingredient $i$ in all users except those in cluster $c$

# %%
specificity_scores = np.zeros((len(filtered_labels), X_normalized.shape[1]))

for i in range(len(filtered_labels)):
    label = filtered_labels[i][0]
        
    distrib_pos = X_normalized[labels==label,:].sum(axis=0)
    distrib_neg = X_normalized[labels!=label,:].sum(axis=0)

    # normalize
    distrib_pos = distrib_pos / distrib_pos.sum()
    distrib_neg = distrib_neg / distrib_neg.sum()
    
    specificity_scores[i] = (distrib_pos - distrib_neg)
    
    distrib_pos = np.array(distrib_pos)[0]
    distrib_neg = np.array(distrib_neg)[0]
    
    print("CLUSTER: ", label, "-"*40 )
    for feat_idx in specificity_scores[i].argsort()[::-1][:10]:
        ingredient_name = ingredientIDText[feat_names[feat_idx]]
        print("-- ", ingredient_name ,specificity_scores[i][feat_idx], distrib_pos[feat_idx], distrib_neg[feat_idx])
# Out:
# CLUSTER:  0 ----------------------------------------
# --  1 (4 ounce) can chopped green chiles (such as Old El Paso®) 0.00283344597109 0.00605118840099 0.0032177424299
# --  1 1/2 cups shredded Monterey Jack cheese 0.00257530083546 0.00594295467255 0.00336765383709
# --  1 tablespoon taco seasoning mix (such as Old El Paso®) 0.00222520003237 0.00496464297026 0.00273944293789
# --  2 (6 ounce) cans black olives, drained 0.00219649698152 0.00511497078792 0.00291847380639
# --  1 (28 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®) 0.00183215461412 0.00389369032753 0.00206153571341
# --  1 (16 ounce) can whole kernel corn, drained 0.00170975776619 0.00481208135333 0.00310232358715
# --  1/2 head iceberg lettuce - rinsed, dried, and chopped 0.001699781103 0.00354388357909 0.00184410247609
# --  1 (15 ounce) can black beans, rinsed 0.0016542917638 0.00477412010085 0.00311982833705
# --  1 (12 ounce) package corn tortillas 0.00161224804822 0.00363648706067 0.00202423901245
# --  3 tablespoons fresh lime juice 0.00159471930966 0.00515136643291 0.00355664712325
# CLUSTER:  72 ----------------------------------------
# --  1/4 cup crumbled feta cheese 0.00395967909095 0.0068014548489 0.00284177575795
# --  1/2 red onion, thinly sliced 0.00299280079766 0.00637441680217 0.0033816160045
# --  1 bunch fresh spinach, stems removed and leaves chopped 0.00258026678273 0.00580148129734 0.00322121451461
# --  1 (15 ounce) can black beans, rinsed 0.00203128607192 0.00514270280636 0.00311141673444
# --  2 cups vegetable broth 0.00197761858194 0.00430875923432 0.00233114065238
# --  2 tablespoons extra virgin olive oil 0.00195136344526 0.00519158349248 0.00324022004723
# --  1 avocado - peeled, pitted and diced 0.0018547356179 0.00420452761012 0.00234979199221
# --  1/2 cup cherry tomatoes, halved 0.00177740512573 0.003086562463 0.00130915733727
# --  1/2 cup cooked quinoa 0.00162128312012 0.00314402987812 0.001522746758
# --  1 cup cubed butternut squash 0.00152172019611 0.002918748395 0.00139702819889
# CLUSTER:  6 ----------------------------------------
# --  2 teaspoons active dry yeast 0.0153915654312 0.0207071419788 0.00531557654757
# --  3 cups bread flour 0.0123517755899 0.0160664137948 0.00371463820495
# --  2 1/4 teaspoons bread machine yeast 0.00397002966699 0.00541800501683 0.00144797534984
# --  2 cups vegetable oil for frying 0.00240389444451 0.00640008647024 0.00399619202573
# --  3 cups whole wheat flour 0.00235954786859 0.00508268085374 0.00272313298515
# --  2 tablespoons cornmeal 0.00223833222145 0.00403840536251 0.00180007314106
# --  1/2 teaspoon kosher salt 0.001958536306 0.00474894350042 0.00279040719441
# --  1 teaspoon sesame oil 0.00193566019675 0.00466216103059 0.00272650083384
# --  3 tablespoons dry milk powder 0.00175296662937 0.00266675701212 0.000913790382748
# --  3 tablespoons rice wine vinegar 0.00124984109294 0.00318585824847 0.00193601715553
# CLUSTER:  26 ----------------------------------------
# --  1 1/3 tablespoons grated fresh ginger 0.00307900290834 0.00695219841215 0.00387319550381
# --  1 teaspoon sesame oil 0.00213226629526 0.0048543016845 0.00272203538924
# --  3 tablespoons rice wine vinegar 0.00211489226454 0.00402952726661 0.00191463500206
# --  2 tablespoons extra virgin olive oil 0.00203061104018 0.00527676310342 0.00324615206324
# --  1/2 red onion, thinly sliced 0.00200143305689 0.0054200394484 0.00341860639151
# --  3 tablespoons fresh lime juice 0.00195376631985 0.00551035996839 0.00355659364854
# --  1/4 cup minced shallot 0.00184393488061 0.00363859099908 0.00179465611847
# --  1/2 teaspoon kosher salt 0.00163915977076 0.0044380388765 0.00279887910574
# --  1 tablespoon drained capers 0.00160745889709 0.00297404659881 0.00136658770172
# --  1 tablespoon chopped fresh thyme 0.00155324925407 0.00355771757035 0.00200446831628
# CLUSTER:  2 ----------------------------------------
# --  4 small Golden Delicious apples - peeled, cored, and chopped 0.00558837278293 0.0064231940937 0.000834821310769
# --  Strawberries 0.00535387551078 0.00811193507474 0.00275805956395
# --  1 tablespoon poppy seeds 0.00528913124603 0.00701584544531 0.00172671419928
# --  2/3 cup dried cranberries 0.00481217068515 0.00663648958069 0.00182431889553
# --  1 1/2 pints fresh raspberries 0.00444752671788 0.00552581275144 0.00107828603355
# --  1 kiwi, sliced 0.00442667190946 0.00517495996444 0.000748288054983
# --  2 tablespoons cinnamon sugar, or as needed 0.00408939349323 0.00476063827064 0.000671244777409
# --  3/4 cup almonds, blanched and slivered 0.00405968687681 0.0048222912156 0.000762604338799
# --  1/3 cup apricot preserves 0.0037508457753 0.00470750398096 0.00095665820566
# --  1 cup white wine vinegar 0.0036346224292 0.0054260033517 0.0017913809225
# CLUSTER:  132 ----------------------------------------
# --  1 (10.75 ounce) can condensed cream of chicken soup 0.00892094913431 0.0126678603834 0.00374691124913
# --  4 boneless pork chops, 1/2 inch thick 0.00873941045145 0.0114214037461 0.00268199329469
# --  1 (1 ounce) package dry onion soup mix 0.00833714407061 0.0112159988448 0.00287885477422
# --  1 (6 ounce) can chopped mushrooms, with liquid 0.00577791102495 0.00815959679824 0.00238168577329
# --  1 (16 ounce) package egg noodles 0.00543459196221 0.00770298068918 0.00226838872697
# --  4 pork chops 0.0047605797562 0.00609516551032 0.00133458575412
# --  2 pounds beef stew meat 0.00440849070851 0.00615032302846 0.00174183231995
# --  2 (10.75 ounce) cans  cream of celery soup, undiluted 0.00429822285244 0.00537347209875 0.0010752492463
# --  2 1/2 cups seasoned dry bread crumbs 0.00381894888462 0.0067936820453 0.00297473316068
# --  1 (16 ounce) jar pasta sauce 0.00374291864186 0.00714941750418 0.00340649886231
# CLUSTER:  17 ----------------------------------------
# --  1 1/3 tablespoons grated fresh ginger 0.00508945224089 0.00896115670109 0.0038717044602
# --  Curry powder to taste 0.00396722958099 0.00685878113896 0.00289155155796
# --  3 tablespoons fresh lime juice 0.00345432149181 0.0070064941228 0.00355217263099
# --  2 tablespoons extra virgin olive oil 0.00335434208542 0.00659954427617 0.00324520219075
# --  1/2 red onion, thinly sliced 0.00328464125408 0.00670264374291 0.00341800248884
# --  1/3 cup coconut milk 0.00324437061214 0.0048317558668 0.00158738525466
# --  1/4 cup crumbled feta cheese 0.00300792893556 0.00591852375318 0.00291059481763
# --  1 teaspoon ground dried turmeric 0.00264877438333 0.00404560849989 0.00139683411657
# --  3 tablespoons rice wine vinegar 0.00258945883236 0.00451707777723 0.00192761894487
# --  1/2 cup cooked quinoa 0.00257148259737 0.00410169875326 0.00153021615589
# CLUSTER:  66 ----------------------------------------
# --  2 teaspoons active dry yeast 0.0417097876562 0.0467701540796 0.00506036642344
# --  3 cups bread flour 0.034715535467 0.0382061510657 0.00349061559868
# --  2 1/4 teaspoons bread machine yeast 0.0107695416226 0.0121515175273 0.00138197590471
# --  3 cups whole wheat flour 0.00737046513622 0.0100393850784 0.00266891994218
# --  2 egg yolks at room temperature 0.00659891978835 0.0104296931267 0.00383077333836
# --  3 tablespoons dry milk powder 0.00589176149502 0.00675884532708 0.000867083832065
# --  3 egg whites 0.00543823184574 0.00871508800062 0.00327685615488
# --  1 1/2 cups buttermilk 0.0049971192538 0.00917949420312 0.00418237494932
# --  2 tablespoons cornmeal 0.00443488268862 0.00622304618924 0.00178816350062
# --  1 (.25 ounce) package rapid rise yeast 0.00408325666149 0.00465209495423 0.000568838292742
# CLUSTER:  101 ----------------------------------------
# --  Strawberries 0.00379312126059 0.00659516595565 0.00280204469506
# --  1 tablespoon poppy seeds 0.00304618645296 0.00482534831747 0.00177916186451
# --  2/3 cup dried cranberries 0.00281282235575 0.00468432902382 0.00187150666807
# --  3/4 cup almonds, blanched and slivered 0.00280898019478 0.00360579974139 0.000796819546604
# --  4 small Golden Delicious apples - peeled, cored, and chopped 0.00250911866677 0.00340845648271 0.000899337815943
# --  1 cup white wine vinegar 0.00241941819331 0.00424265647307 0.00182323827976
# --  1/2 red onion, thinly sliced 0.00231982980627 0.0057588347224 0.00343900491612
# --  2 tablespoons toasted sesame seeds 0.00226740022078 0.00459632603061 0.00232892580983
# --  1/3 cup orange juice 0.00223335364912 0.00527675071428 0.00304339706516
# --  1 kiwi, sliced 0.00202702046222 0.00282590676606 0.000798886303842
# CLUSTER:  22 ----------------------------------------
# --  2/3 cup dried cranberries 0.00357535124221 0.00543835500998 0.00186300376778
# --  1 bunch fresh spinach, stems removed and leaves chopped 0.00333692007782 0.00659165612804 0.00325473605022
# --  1 (15 ounce) can garbanzo beans, drained 0.00329969551086 0.00558055959712 0.00228086408626
# --  2 cups vegetable broth 0.00307843348219 0.00542877005713 0.00235033657494
# --  1 tablespoon poppy seeds 0.00292255127935 0.00470434572949 0.00178179445014
# --  1 (15 ounce) can black beans, rinsed 0.00276004470846 0.00589619102036 0.0031361463119
# --  1 cup white wine vinegar 0.00273068788756 0.00455091036251 0.00182022247495
# --  1/2 cup cooked quinoa 0.00261411602598 0.00415147287547 0.00153735684949
# --  3/4 cup almonds, blanched and slivered 0.00249769163514 0.00329939918688 0.000801707551744
# --  1/2 red onion, thinly sliced 0.00245434350079 0.0058925013956 0.0034381578948

# %% [markdown]
# ## Computing similarity between clusters and recipes
#
# To compute the similarity score between a recipe and a cluster, we compute the average specificity of the ingredients of the recipe for the cluster:
#
# $$ S_{CR} = \frac{1}{|R|} \sum_{i \in R} s_{ci} $$

# %%
recipeIngredientsList = {}
for recipe in recipeIngredients:
    recipeIngredientsList[recipe] = list(map(lambda x: x["id"],recipeIngredients[recipe]))

# %%
def computeRecipesSimilarity(recipe, cluster_index):
    ingredients = recipeIngredientsList[recipe]
    
    similarity = np.array(list(map(lambda x: specificity_scores[cluster_index][reverseIngredientsMap[x]], filter(lambda x: x in reverseIngredientsMap, ingredients)))).mean()
    return similarity

# %%
recipesClusterDF = pd.DataFrame()
for i in range(len(filtered_labels)):
    cluster = filtered_labels[i][0]
    recipesClusterDF[cluster] = list(map(lambda x: computeRecipesSimilarity(x, i), recipes))
# Out:
# /home/nathan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: Mean of empty slice.
# /home/nathan/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
list(filter(lambda x: x in reverseIngredientsMap, recipeIngredientsList[recipes[0]]))
# Out:
# []

# %%
recipeIngredients[recipes[0]]
# Out:
# [{'id': '6300', 'text': '1 cup vegetable shortening'},
#  {'id': '1526', 'text': '1 cup white sugar'},
#  {'id': '16278', 'text': '1/4 cup milk'},
#  {'id': '16317', 'text': '2 eggs'},
#  {'id': '16424', 'text': '1 teaspoon vanilla extract'},
#  {'id': '1684', 'text': '3 cups all-purpose flour'},
#  {'id': '16421', 'text': '1 teaspoon salt'},
#  {'id': '2359', 'text': '1 teaspoon baking soda'},
#  {'id': '16157', 'text': '1/4 cup butter'},
#  {'id': '1527', 'text': "3 cups confectioners' sugar"},
#  {'id': '16424', 'text': '1 1/2 teaspoons vanilla extract, or more to taste'},
#  {'id': '16278', 'text': '2 tablespoons milk, or as needed'}]

# %%
clustersOrderedRecipesDF = pd.DataFrame()
for cluster in recipesClusterDF:
    clustersOrderedRecipesDF[cluster] = list(map(lambda x: recipes[x], recipesClusterDF.sort_values([cluster], ascending=False)[cluster].index))

# %%
clustersOrderedRecipesDF.head()
# Out:
#       0       72      6       26      2       132     17      66      101  \
# 0  163703   76942   70048  211466  231066  106184  213948    6996  244453
# 1  245961  177115  242456   24381  255931   11804   85132  234424   86374
# 2   14855  233408    6758  220522  233281    8617  211466  257199  258232
# 3   21660   50648    7138   85132  247061    8867  256207  235292   38410
# 4  247375  229776    7065   25907  234939  228409   25907   70048   16993
#
#       22
# 0  241580
# 1  256351
# 2  229159
# 3  141933
# 4  159632

# %%
clustersOrderedRecipesTitleDF = pd.DataFrame()
for cluster in clustersOrderedRecipesDF:
    clustersOrderedRecipesTitleDF[cluster] = clustersOrderedRecipesDF[cluster].map(lambda x: recipesIDNames[x])

# %%
clustersOrderedRecipesTitleDF.head(10)
# Out:
#                                         0    \
# 0                          Green Chili Eggs
# 1      White Bean Chicken Chili from Knorr®
# 2                       Suzy's Potato Skins
# 3                      Chile Cheese Squares
# 4                     Jan's Chile Con Queso
# 5                  My Favorite Mexican Rice
# 6                 Mushroom Stuffed Zucchini
# 7                    Caitlin's Mexican Rice
# 8  Rice With Olives And Green Chile Peppers
# 9                        Beth's Tex Mex Dip
#
#                                      72   \
# 0                  Oregano-Flavored Feta
# 1                Feta-Stuffed Hamburgers
# 2                         Quickie Kajmak
# 3                              Feta Eggs
# 4                Stuffed Zucchini Shells
# 5                            Egg Muffins
# 6                Simplistic Pepper Salad
# 7  Crustless Spinach and Mushroom Quiche
# 8       Chef John's Spinach and Feta Pie
# 9                   Classic Deviled Eggs
#
#                                      6    \
# 0  Simple and Tasty Chinese Steamed Buns
# 1                            Breadsticks
# 2                     Unbelievable Rolls
# 3                  Southern Butter Rolls
# 4                      French Herb Bread
# 5                          Cheddar Rolls
# 6                       Butter Crescents
# 7                             Snail Pale
# 8                      Buttery Pan Rolls
# 9                        Breakfast Bread
#
#                                      26   \
# 0              Chicken with Ginger Pesto
# 1         Japanese Ginger Salad Dressing
# 2             Hearty Irish Egg Drop Soup
# 3                    Ginger Garlic Paste
# 4                  Buttered Ginger Sauce
# 5        Sweet, Sticky and Spicy Chicken
# 6  Warm Lemon, Honey, and Ginger Soother
# 7             Hot and Sweet Ginger Drink
# 8      Fish and Things Teriyaki Marinade
# 9                 Cauliflower Fried Rice
#
#                                     2                                    132  \
# 0           Blue Ribbon Apple Crumb Pie    Simple Creamy Lemon Chicken Sauce
# 1                 Baked Cinnamon Apples                       Mushroom Sauce
# 2                           Apple Chips                       Creamy Chicken
# 3   Coconut Minis Vanilla Sandwich Cake                   Sour Cream Chicken
# 4                 Strawberry Soda Syrup                        Knoepfla Soup
# 5       Double Berry Brownie Yogurt Cup          Sour Cream Mushroom Chicken
# 6          Valentine Night Strawberries   Easy Sour Cream Scalloped Potatoes
# 7                        Strawberry Jam                    Saucy Chicken Dip
# 8  Cheesecake Fruit Dip from Reddi-wip®                     Potatoes Supreme
# 9                  Strawberry Nut Bread  Pork Chop and Cheesy Rice Casserole
#
#                               17                                     66   \
# 0    Poached Eggs in Ginger Syrup                      Cinnamon Rolls II
# 1             Ginger Garlic Paste            How to Make Cronuts, Part I
# 2       Chicken with Ginger Pesto                 Thin Crust Pizza Dough
# 3          Cauliflower Fried Rice                     Parker House Rolls
# 4           Buttered Ginger Sauce  Simple and Tasty Chinese Steamed Buns
# 5      Hot and Sweet Ginger Drink                      Sourdough Starter
# 6              Honey Garlic Sauce                                 Placek
# 7  Crystallized or Candied Ginger                        Yeast Dumplings
# 8            Itsmeatshuddupneatit         Cream Cheese Danish Coffeecake
# 9                     Gingeradish                    Sunday Dinner Rolls
#
#                                          101  \
# 0                         Canadian Flag Cake
# 1             Strawberry Cream Cheese Spread
# 2  Cookie Crumb Chocolate Covered Strawberry
# 3                             Strawberry Jam
# 4                           Strawberry Pizza
# 5                 Strawberry Apple Baby Food
# 6                     Strawberries and Cream
# 7            Double Berry Brownie Yogurt Cup
# 8                      One-Ingredient Sorbet
# 9                Aunt Kate's Strawberry Cake
#
#                                                  22
# 0                             Cranberry Lemon Scones
# 1                    Banana Walnut Cranberry Muffins
# 2  Dried Bloody Scabs (Halloween Craisin® Appetizer)
# 3                              Banana-Zucchini Bread
# 4                                Baked Stuffed Apple
# 5                          Spinach and Bacon Chicken
# 6                                      Spinach Saute
# 7                                   Spinach Brownies
# 8                                      Baked Spinach
# 9                           Lisa's 1-Skillet Chicken

# %% [markdown]
# ## Evaluating Recipes HealthScore in Clusters

# %%
recipeHealthPopularity = pd.read_csv("data/HealthPopularity.csv")

# %%
ClusterHealthScores = pd.DataFrame()

mexicanClusterHealthScores = []
for recipe_id in clustersOrderedRecipesDF[0].head(100):
    with open('recipe_data/' + recipe_id + "/healthscore.json", 'r') as infile:
        mexicanClusterHealthScores.append(json.load(infile)["score"])
ClusterHealthScores["Mexican"] = mexicanClusterHealthScores

asianClusterHealthScores = []
for recipe_id in clustersOrderedRecipesDF[26].head(100):
    with open('recipe_data/' + recipe_id + "/healthscore.json", 'r') as infile:
        asianClusterHealthScores.append(json.load(infile)["score"])
ClusterHealthScores["Asian"] = asianClusterHealthScores

sauceClusterHealthScores = []
for recipe_id in clustersOrderedRecipesDF[132].head(100):
    with open('recipe_data/' + recipe_id + "/healthscore.json", 'r') as infile:
        sauceClusterHealthScores.append(json.load(infile)["score"])
ClusterHealthScores["Sauce"] = sauceClusterHealthScores

# %%
with sns.plotting_context("notebook", font_scale=3):
    allHealthScore = recipeHealthPopularity["HealthScore"]
    allHealthScore.name = "All Healthscore"
    plotHealthHistogram([ClusterHealthScores[ClusterHealthScores["Mexican"]>=4]["Mexican"], allHealthScore])

# %%
with sns.plotting_context("notebook", font_scale=3):
    allHealthScore = recipeHealthPopularity["HealthScore"]
    allHealthScore.name = "All Healthscore"
    plotHealthHistogram([ClusterHealthScores[ClusterHealthScores["Asian"]>=4]["Asian"], allHealthScore])

# %%
with sns.plotting_context("notebook", font_scale=3.):
    allHealthScore = recipeHealthPopularity["HealthScore"]
    allHealthScore.name = "All Healthscore"
    plotHealthHistogram([ClusterHealthScores[ClusterHealthScores["Sauce"] >= 4]["Sauce"], allHealthScore])
