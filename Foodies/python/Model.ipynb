# %% [markdown]
# # Recipe Recommender System Model
#
# This notebook presents the python code used to build a recipe recommender system based on BPR.

# %%
import os
import json
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import pylab as pl
from util import *
# %matplotlib inline

# %% [markdown]
# ## Made-it interactions load

# %%
recipes = [f.path.split("/")[1] for f in os.scandir("recipe_data/") if f.is_dir() ]

# %%
with open("data/user_data.json", "r") as in_file:
    users_data = json.load(in_file)

# %%
len(users_data.keys())
# Out:
# 1017178

# %%
recipesDict = {}
for recipe in recipes:
    recipesDict[recipe] = True
    
userRecipes = {}
for user in users_data.keys():
    userRecipes[user] = list(filter(lambda x: str(x) in recipesDict, users_data[user]["made"]))

# %%
nb_interactions = 0
for user in userRecipes.keys():
    nb_interactions += len(userRecipes[user])
nb_interactions
# Out:
# 4402092

# %%
recipeUsers = {}
for user in userRecipes.keys():
    for recipe in userRecipes[user]:
        if recipe in recipeUsers:
            recipeUsers[recipe].append(user)
        else:
            recipeUsers[recipe] = [user]

# %%
with open("data/madeUserRecipes.json", "w") as file:
    file.write(json.dumps(userRecipes))

with open("data/madeRecipeUsers.json", "w") as file:
    file.write(json.dumps(recipeUsers))

# %%
with open("data/madeUserRecipes.json", "r") as file:
    userRecipes = json.loads(file.read())

with open("data/madeRecipeUsers.json", "r") as file:
    recipeUsers = json.loads(file.read())

# %% [markdown]
# ## Reviews interaction load

# %%
recipes = [f.path.split("/")[1] for f in os.scandir("recipe_data/") if f.is_dir() ]    
print(recipes[:10])
print("Nb of recipes: " + str(len(recipes)))

# %%
def getAllUsersWithReviews(start_path, files):
    users = set()
    for file in files:
        try:
            with open(start_path + file + "/reviews.json") as data_file:    
                reviews = json.load(data_file)
                for review in reviews:
                    users.add(review["submitter"]["userID"])
        except: 
            print("Problem with file: " + file)
    return users

# %%
users = getAllUsersWithReviews("recipe_data/", recipes)

# %%
len(users)
# Out:
# 1017178

# %%
userRecipes = {}
recipeUsers = {}

for user in users:
    userRecipes[user] = []

for recipe in recipes:
    recipeUsers[recipe] = []

for recipe in recipes:
    with open("recipe_data/" + recipe + "/reviews.json") as data_file:
        reviews = json.load(data_file)
        for review in reviews:
            user = review["submitter"]["userID"]
            userRecipes[user].append(recipe)
            recipeUsers[recipe].append(user)

# %%
with open("data/reviewUserRecipes.json", "w") as file:
    file.write(json.dumps(userRecipes))

with open("data/reviewRecipeUsers.json", "w") as file:
    file.write(json.dumps(recipeUsers))

# %%
with open("data/reviewUserRecipes.json", "r") as file:
    userRecipes = json.loads(file.read())

with open("data/reviewRecipeUsers.json", "r") as file:
    recipeUsers = json.loads(file.read())

# %% [markdown]
# ## Interactions Analysis

# %%
users = list(userRecipes.keys())
recipes = list(recipeUsers.keys())

# %%
userDistrib = list(map(lambda x: len(userRecipes[x]), users))
fig = pl.gcf()
fig.set_size_inches(14, 8)
plt.hist(userDistrib, bins=35,log=True)
pl.title('Distribution of #interactions amongst users')
pl.xlabel('Interactions')
pl.ylabel('#Users')
font = {'family' : 'sans-serif',
        'size'   : 16}

axes = plt.gca()
axes.set_ylim([0.9,10**7])
matplotlib.rc('font', **font)
plt.show()

# %%
plt.hist(userDistrib, log=True, bins=np.sqrt(3)**(np.arange(0,15)))
fig = pl.gcf()
fig.set_size_inches(14, 8)
plt.xscale('log')

pl.title('Distribution of #interactions amongst users - LogLog scale')
pl.xlabel('Interactions')
pl.ylabel('#Users')

axes = plt.gca()
axes.set_ylim([0.9,10**7])
matplotlib.rc('font', **font)
plt.show()

# %%
pdUserDistrib = pd.DataFrame(userDistrib)
pdUserDistrib.columns = ["users interactions"]
pdUserDistrib.describe()
# Out:
#        users interactions
# count        1.017178e+06
# mean         4.327750e+00
# std          1.627038e+01
# min          0.000000e+00
# 25%          1.000000e+00
# 50%          1.000000e+00
# 75%          3.000000e+00
# max          3.584000e+03

# %%
for i in [3, 5, 10, 20, 50, 100]:
    print(str(len(pdUserDistrib[pdUserDistrib["users interactions"] >= i])) + " users with at least than " + str(i) + " interactions")
# Out:
# 329077 users with at least than 3 interactions
# 191628 users with at least than 5 interactions
# 85931 users with at least than 10 interactions
# 34406 users with at least than 20 interactions
# 7870 users with at least than 50 interactions
# 3339 users with at least than 100 interactions

# %%
recipeDistrib = list(map(lambda x: len(recipeUsers[x]), recipes))
fig = pl.gcf()
pl.title('Distribution of #interactions amongst recipes - LogLog scale')
pl.xlabel('Interactions')
pl.ylabel('#Recipes')
fig.set_size_inches(14, 8)
plt.hist(recipeDistrib,  log=True)
plt.show()

# %%
plt.hist(recipeDistrib, log=True, bins=np.sqrt(3)**(np.arange(0,15)))
fig = pl.gcf()
fig.set_size_inches(14, 8)
plt.xscale('log')

pl.title('Distribution of #interactions amongst recipes - LogLog scale')
pl.xlabel('Interactions')
pl.ylabel('#Recipes')

axes = plt.gca()
matplotlib.rc('font', **font)
plt.show()

# %%
pdrecipeDistrib = pd.DataFrame(recipeDistrib)
pdrecipeDistrib.columns = ["recipes interactions"]
pdrecipeDistrib.describe()
# Out:
#        recipes interactions
# count          38677.000000
# mean             113.816790
# std              412.491537
# min                1.000000
# 25%                7.000000
# 50%               22.000000
# 75%               74.000000
# max            14620.000000

# %% [markdown]
# ## Cleaning data

# %%
cleanedUserRecipes = {}
cleanedRecipeUsers = {}

for user, recipes in userRecipes.items():
    if len(recipes) >= 10 and len(recipes) < 200:
        cleanedUserRecipes[user] = recipes
        for recipe in recipes:
            if recipe in cleanedRecipeUsers.keys():
                cleanedRecipeUsers[recipe].extend([user])
            else:
                cleanedRecipeUsers[recipe] = [user]

# %%
# REMOVE POPULAR RECIPE
'''userRecipes = cleanedUserRecipes
recipeUsers = cleanedRecipeUsers
cleanedUserRecipes = {}
cleanedRecipeUsers = {}

for recipe, users in recipeUsers.items():
    if len(users) >= 10 and len(users) < 500:
        cleanedRecipeUsers[recipe] = users
        for user in users:
            if user in cleanedUserRecipes.keys():
                cleanedUserRecipes[user].extend([recipe])
            else:
                cleanedUserRecipes[user] = [recipe]
                '''
# Out:
# 'userRecipes = cleanedUserRecipes\nrecipeUsers = cleanedRecipeUsers\ncleanedUserRecipes = {}\ncleanedRecipeUsers = {}\n\nfor recipe, users in recipeUsers.items():\n    if len(users) >= 10 and len(users) < 500:\n        cleanedRecipeUsers[recipe] = users\n        for user in users:\n            if user in cleanedUserRecipes.keys():\n                cleanedUserRecipes[user].extend([recipe])\n            else:\n                cleanedUserRecipes[user] = [recipe]\n                '

# %%
def cleanSmall(UserRecipes, RecipeUsers, threshold):
    
    cleaned = False
    while cleaned == False:
    
        nbUsers = len(UserRecipes.keys())
        nbRecipes = len(RecipeUsers.keys())

        print("Cleaning users and recipes with less than " + str(threshold) + " reviews")
        print("Number of users: "  + str(nbUsers))
        print("Number of recipes: "  + str(nbRecipes))

        toRemove = []
        for recipe, users in RecipeUsers.items():
            if len(users) < threshold:
                toRemove.extend([recipe])

        for recipe in toRemove:
            RecipeUsers.pop(recipe)

        UserRecipes = {}
        for recipe, users in RecipeUsers.items():
            for user in users:
                if user in UserRecipes.keys():
                    UserRecipes[user].extend([recipe])
                else:
                    UserRecipes[user] = [recipe]

        toRemove= []
        for user, recipes in UserRecipes.items():
            if len(recipes) < threshold:
                toRemove.extend([user])

        for user in toRemove:
            UserRecipes.pop(user) 

        RecipeUsers = {}
        for user, recipes in UserRecipes.items():
            for recipe in recipes:
                if recipe in RecipeUsers.keys():
                    RecipeUsers[recipe].extend([user])
                else:
                    RecipeUsers[recipe] = [user]   

        if len(UserRecipes.keys()) == nbUsers and len(RecipeUsers.keys()) == nbRecipes:
            cleaned = True
    return UserRecipes, RecipeUsers

# %%
userRecipes, recipeUsers = cleanSmall(cleanedUserRecipes, cleanedRecipeUsers, 10)
# Out:
# Cleaning users and recipes with less than 10 reviews
# Number of users: 85019
# Number of recipes: 34755
# Cleaning users and recipes with less than 10 reviews
# Number of users: 81823
# Number of recipes: 18448
# Cleaning users and recipes with less than 10 reviews
# Number of users: 81740
# Number of recipes: 18240
# Cleaning users and recipes with less than 10 reviews
# Number of users: 81735
# Number of recipes: 18228

# %%
users = list(userRecipes.keys())
recipes = list(recipeUsers.keys())

# %%
min(map(lambda x: len(recipeUsers[x]), recipeUsers.keys()))
# Out:
# 10

# %%
min(map(lambda x: len(userRecipes[x]), userRecipes.keys()))
# Out:
# 10

# %%
nbUsers = len(userRecipes.keys())
nbRecipes = len(recipeUsers.keys())
nbInteractions = sum(list(map(lambda x: len(recipeUsers[x]), recipeUsers.keys())))
print("Number of users: "  + str(nbUsers))
print("Number of recipes: "  + str(nbRecipes))
print("Number of interactions: "  + str(nbInteractions))
# Out:
# Number of users: 81735
# Number of recipes: 18228
# Number of interactions: 2042333

# %% [markdown]
# ## Building Model

# %%
'''# Sample 1000 recipes and 10000 users for test
N = 1000
M = 10000

sampleRecipes = np.random.choice(list(recipes), N)
sampleUsers = []
while len(sampleUsers) < M:
    r = np.random.choice(sampleRecipes)
    if(len(recipeUsers[r]) > 1):
        u = np.random.choice(recipeUsers[r])
        if str(u) not in sampleUsers:
            sampleUsers.append(str(u))
            '''
# Out:
# '# Sample 1000 recipes and 10000 users for test\nN = 1000\nM = 10000\n\nsampleRecipes = np.random.choice(list(recipes), N)\nsampleUsers = []\nwhile len(sampleUsers) < M:\n    r = np.random.choice(sampleRecipes)\n    if(len(recipeUsers[r]) > 1):\n        u = np.random.choice(recipeUsers[r])\n        if str(u) not in sampleUsers:\n            sampleUsers.append(str(u))\n            '

# %%
  '''W = np.zeros((N,M))
for i in range(N):
    for j in range(M):
        if sampleRecipes[i] in userRecipes[sampleUsers[j]]:
            W[i,j] = 1  '''
# Out:
# 'W = np.zeros((N,M))\nfor i in range(N):\n  for j in range(M):\n      if sampleRecipes[i] in userRecipes[sampleUsers[j]]:\n          W[i,j] = 1  '

# %%
  '''sampleInteractions = []

for user in sampleUsers:
    for recipe in sampleRecipes:
        if recipe in userRecipes[user]:
            sampleInteractions.append((recipe, user))  '''
# Out:
# 'sampleInteractions = []\n\nfor user in sampleUsers:\n  for recipe in sampleRecipes:\n      if recipe in userRecipes[user]:\n          sampleInteractions.append((recipe, user))  '

# %%
interactions = []
for user in users:
    for recipe in userRecipes[user]:
        interactions.append((recipe, user))

#interactions = np.array(sampleInteractions)

# %% [markdown]
# ## Export interactions

# %%
dfInteractions = pd.DataFrame(interactions)
dfInteractions.columns = ["item", "user"]
dfInteractions["item"] = pd.factorize(dfInteractions["item"])[0]
dfInteractions["user"] = pd.factorize(dfInteractions["user"])[0]

# %%
dfInteractions.to_csv("data/interactions.csv")

# %%
popInt = list(map(lambda x: len(recipeUsers[x[0]]), interactions))
sum(popInt) / len(popInt)
# Out:
# 810.9966743914924

# %%
arr = np.array(interactions)
np.random.shuffle(arr)
test = {}
test_te = []

for i in range(len(arr)):
    user = arr[i][1]
    if user not in test:
        test_te.append(arr[i])
        test[user] = True

# %%
popInt = list(map(lambda x: len(recipeUsers[int(x[0])]), test_te))
sum(popInt) / len(popInt)
# Out:
# 837.5526151587447

# %%
len(test_te)
# Out:
# 81735

# %% [markdown]
# ## Sample data

# %%
#interactions = np.random.choice(interactions, size = len(interactions)/10)

# %% [markdown]
# ## Use sample instead of real values

# %%
'''recipes = sampleRecipes
users = sampleUsers
interactions = sampleInteractions  '''
# Out:
# 'recipes = sampleRecipes\nusers = sampleUsers\ninteractions = sampleInteractions  '

# %% [markdown]
# ## Model

# %%
userDict = {}
for i in range(len(users)):
    userDict[users[i]] = i
    
recipeDict = {}
for i in range(len(recipes)):
    recipeDict[recipes[i]] = i

# %%
def sample_neg_pop(interactions, user, userRecipes):
    interaction  = interactions[np.random.randint(0, len(interactions))]
    recipe = interaction[0]
    while recipe in userRecipes[user]:    
        interaction  = interactions[np.random.randint(0, len(interactions))]
        recipe = interaction[0]
    return recipe

# %%
def sample_neg(recipes, user, userRecipes):
    recipe  = recipes[np.random.randint(0, len(recipes))]
    while recipe in userRecipes[user]:
        recipe  = recipes[np.random.randint(0, len(recipes))]
    return recipe

# %%
# Split test-train 

userRecipes_tr = {}
recipeUsers_tr = {}
for interaction in interactions:
    r = interaction[0]
    u = interaction[1]
    if u not in userRecipes_tr.keys():
        userRecipes_tr[u] = [r]
    else:
        userRecipes_tr[u].append(r)
    if r not in recipeUsers_tr.keys():
        recipeUsers_tr[r] = [u]
    else:
        recipeUsers_tr[r].append(u)
        

interactions_te = []
userRecipes_te = {}
for user in userRecipes_tr.keys():
    test_recipe = np.random.choice(userRecipes_tr[user])
    userRecipes_tr[user].remove(test_recipe)
    recipeUsers_tr[test_recipe].remove(user)
    userRecipes_te[user] = test_recipe
    interactions_te.append((test_recipe, user))

interactions_tr = []
for user in userRecipes_tr.keys():
    for recipe in userRecipes_tr[user]:
        interactions_tr.append((recipe, user))

# %% [markdown]
# ### Weight interactions inversely to popularity

# %%
# Returns an array with interactions duplicated according to the inverse frequency of the recipe
# An interaction with the most popular recipe will be present only once in the array.
def probWeightedInteractions(interactions, recipeUsers, power = 0):
    apps = np.zeros((len(interactions)))
    for i in range(len(interactions)):
        apps[i] = (len(recipeUsers[interactions[i][0]]))
    factor = max(apps)**(1 - power)
    weighted_inter =np.zeros((len(interactions)))
    for i in range(len(apps)):
        weighted_inter[i] = 1 / apps[i] * (apps[i]**power) * factor
        
    interactions_array = []
    for i in range(int(len(interactions))):
        for j in range(int(round(weighted_inter[i]))):
            interactions_array.append(interactions[i])
    return interactions_array

# %% [markdown]
# Let's check the effect of the method

# %%
from collections import Counter

def plotInteractionDistrib(interactions_list, legends = None):
    for i in range(len(interactions_list)): 
        interactions = interactions_list[i]
        recipes = list(map(lambda x: x[0], interactions))
        c = Counter(recipes)
        count = list(map(lambda x: c[x], c.keys()))
        count = sorted(count)
        if legends:
            plt.plot(count, label="x = " + str(legends[i]))
            plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        else:
            plt.plot(count)
    fig = plt.gcf()
    fig.set_size_inches(12,7)
    plt.title("Recipes ordered by #Interactions")
    plt.show()

# %%
plotInteractionDistrib([interactions_tr])

# %%
powers = [1, 7/8, 3/4]
plotInteractionDistrib(list(map(lambda x: probWeightedInteractions(interactions_tr, recipeUsers, x), powers)), powers)

# %% [markdown]
# ## Bayesian Personalized Ranking

# %%
def BPR(interactions_tr, interactions_te, bias, alpha = 0.01, _lambda = 0.01, K = 30, P = None, Q = None, prob = False, power = 0, _iter = 25*10**6, _pop = False):
        
    print("BPR with K: " + str(K))

    aucs = []

    # Initialize low-rank matrices with random values
    if P is None or Q is None:
        sigma = 0.1; # std for random initialization
        mu = 0.0; # mean for random initialization
        N = len(users)
        M = len(recipes)
        P = ((np.random.rand(N,K) * 4) - 2) * sigma # Users
        Q = ((np.random.rand(K,M) * 4) - 2) * sigma # Recipes
    
    b = np.zeros(len(recipes))
    
    if(prob):
        interactions_tr = probWeightedInteractions(interactions_tr, recipeUsers, power)
        print("done")

    for step in range(_iter + 1):

        # Select a random positive example
        i  = interactions_tr[np.random.randint(0, len(interactions_tr))]
        recipe = i[0]
        user = i[1]
        ir = recipeDict[recipe]
        iu = userDict[user]

        # Sample a negative example
        if(_pop):
            ji = recipeDict[sample_neg_pop(interactions_tr, user, userRecipes_tr)]
        else:
            ji = recipeDict[sample_neg(recipes, user, userRecipes_tr)]

        # See BPR paper for details
        px = np.dot(P[iu,:], (Q[:,ir]-Q[:,ji]))
        if bias:
            px += (b[ir]-b[ji]) 
        z = 1 / (1 + np.exp(px))

        # update P
        d = (Q[:,ir]-Q[:,ji])*z - _lambda*P[iu,:].T
        P[iu,:] = P[iu,:] + alpha*d.T

        # update Q positive 
        d = P[iu,:]*z - _lambda*Q[:,ir].T
        Q[:,ir] = Q[:,ir] + alpha*d.T

        # update Q negative
        d = -P[iu,:]*z - _lambda*Q[:,ji].T
        Q[:,ji] = Q[:,ji] + alpha*d.T

        if bias:
            # neg
            d = -z - _lambda*b[ji]
            b[ji] = b[ji] + alpha*d

            # pos
            d = z - _lambda*b[ir]
            b[ir] = b[ir] + alpha*d

        if step % 500000 == 0:
            print("Computing AUC...")
            # Compute the Area Under the Curve (AUC)
            auc = 0
            auc_non_un = 0
            fails = []
            for interaction in interactions_te:
                recipe = interaction[0]
                user = interaction[1]
                
                
                
                n_recipe = sample_neg(recipes, user, userRecipes)
                
                ir = recipeDict[recipe]
                iu = userDict[user]
                ji = recipeDict[n_recipe]

                sp = np.dot(P[iu,:],Q[:,ir])
                sn = np.dot(P[iu,:],Q[:,ji])
                
                if bias:
                    sp += b[ir]
                    sn += b[ji]

                if sp > sn:
                    auc = auc+1
                else:
                    fails.append((recipe, n_recipe))
                    if sp == sn:
                        auc = auc+0.5
                        '''
                if prob:
                    n_recipe_non_un = sample_neg(interactions, user, userRecipes)[0]
                    ji_non_un = recipeDict[n_recipe_non_un]
                    sn_non_un = np.dot(P[iu,:],Q[:,ji_non_un])
                    
                    if bias:
                        sn_non_un += b[ji]
                    
                    if sp > sn_non_un:
                        auc_non_un = auc_non_un+1
                    else:
                        if sp == sn_non_un:
                            auc_non_un = auc_non_un+0.5
                            '''

            auc = auc / len(userRecipes_te.keys())
            print("AUC test: " + str(auc))
            
            aucs.append(auc)
            
            '''
            if prob:
                auc_non_un = auc_non_un / len(userRecipes_te.keys())
                print("non-uniform AUC test: " + str(auc_non_un))
            '''
            
    return fails, aucs

# %%
mu = 0.0; # mean for random initialization
N = len(users)
M = len(recipes)
K = 30
sigma = 0.1; # std for random initialization
uFactors = ((np.random.rand(N,K) * 4) - 2) * sigma # Users
rFactors = ((np.random.rand(K,M) * 4) - 2) * sigma # Recipes

# %%
non_uni = BPR(interactions_tr, interactions_te, False, P=uFactors, Q=rFactors, alpha=0.01, _lambda=0.01, K=30, prob=False, _pop=True, _iter = 50*10**6)
# Out:
# BPR with K: 30
# Computing AUC...
# AUC test: 0.6696641585612039
# Computing AUC...
# AUC test: 0.6715850003058665
# Computing AUC...
# AUC test: 0.6699455557594666
# Computing AUC...
# AUC test: 0.671756285556983
# Computing AUC...
# AUC test: 0.6694072306845292
# Computing AUC...
# AUC test: 0.6696396892396158
# Computing AUC...
# AUC test: 0.6729797516363859
# Computing AUC...
# AUC test: 0.6732122101914725
# Computing AUC...
# AUC test: 0.6723435492750963
# Computing AUC...
# AUC test: 0.6729919862971799
# Computing AUC...
# AUC test: 0.6708998593014008
# Computing AUC...
# AUC test: 0.6706429314247262
# Computing AUC...
# AUC test: 0.6730409249403561
# Computing AUC...
# AUC test: 0.6730898635835322
# Computing AUC...
# AUC test: 0.6733100874778247
# Computing AUC...
# AUC test: 0.6737138312840276
# Computing AUC...
# AUC test: 0.672600477151771
# Computing AUC...
# AUC test: 0.6726494157949471
# Computing AUC...
# AUC test: 0.6733590261210008
# Computing AUC...
# AUC test: 0.6726616504557411
# Computing AUC...
# AUC test: 0.6726494157949471
# Computing AUC...
# AUC test: 0.6743133296629351
# Computing AUC...
# AUC test: 0.6751697559185171
# Computing AUC...
# AUC test: 0.6724536612222426
# Computing AUC...
# AUC test: 0.6736526579800575
# Computing AUC...
# AUC test: 0.6747048388083441
# Computing AUC...
# AUC test: 0.6735180767113231
# Computing AUC...
# AUC test: 0.6738973511959381
# Computing AUC...
# AUC test: 0.675916070226953
# Computing AUC...
# AUC test: 0.6725760078301829
# Computing AUC...
# AUC test: 0.6735303113721172
# Computing AUC...
# AUC test: 0.6772374135927082
# Computing AUC...
# AUC test: 0.6736648926408515
# Computing AUC...
# AUC test: 0.6733467914602068
# Computing AUC...
# AUC test: 0.6753288065088395
# Computing AUC...
# AUC test: 0.6753165718480455
# Computing AUC...
# AUC test: 0.6744846149140515
# Computing AUC...
# AUC test: 0.6753288065088395
# Computing AUC...
# AUC test: 0.6745947268611978
# Computing AUC...
# AUC test: 0.676748027160947
# Computing AUC...
# AUC test: 0.6758059582798067
# Computing AUC...
# AUC test: 0.6742399216981709
# Computing AUC...
# AUC test: 0.674668134825962
# Computing AUC...
# AUC test: 0.6765278032666544
# Computing AUC...
# AUC test: 0.6737383006056157
# Computing AUC...
# AUC test: 0.6760995901388634
# Computing AUC...
# AUC test: 0.6758793662445709
# Computing AUC...
# AUC test: 0.6750596439713709
# Computing AUC...
# AUC test: 0.6740564017862605
# Computing AUC...
# AUC test: 0.6764543953018902
# Computing AUC...
# AUC test: 0.676748027160947
# Computing AUC...
# AUC test: 0.6736648926408515
# Computing AUC...
# AUC test: 0.6749495320242246
# Computing AUC...
# AUC test: 0.677188474949532
# Computing AUC...
# AUC test: 0.6757570196366306
# Computing AUC...
# AUC test: 0.6772129442711201
# Computing AUC...
# AUC test: 0.677995962561938
# Computing AUC...
# AUC test: 0.6769437817336514
# Computing AUC...
# AUC test: 0.6747660121123142
# Computing AUC...
# AUC test: 0.6774086988438246
# Computing AUC...
# AUC test: 0.6736281886584694
# Computing AUC...
# AUC test: 0.6777023307028812
# Computing AUC...
# AUC test: 0.6757937236190127
# Computing AUC...
# AUC test: 0.6752431638832813
# Computing AUC...
# AUC test: 0.6772863522358843
# Computing AUC...
# AUC test: 0.6774331681654127
# Computing AUC...
# AUC test: 0.6754389184559858
# Computing AUC...
# AUC test: 0.6764421606410962
# Computing AUC...
# AUC test: 0.6777879733284394
# Computing AUC...
# AUC test: 0.6772985868966783
# Computing AUC...
# AUC test: 0.677616688077323
# Computing AUC...
# AUC test: 0.6770416590200037
# Computing AUC...
# AUC test: 0.6756346730286903
# Computing AUC...
# AUC test: 0.6754633877775739
# Computing AUC...
# AUC test: 0.6777757386676454
# Computing AUC...
# AUC test: 0.6772496482535022
# Computing AUC...
# AUC test: 0.6764666299626843
# Computing AUC...
# AUC test: 0.6774086988438246
# Computing AUC...
# AUC test: 0.676772496482535
# Computing AUC...
# AUC test: 0.6774454028262067
# Computing AUC...
# AUC test: 0.6754511531167798
# Computing AUC...
# AUC test: 0.6779837279011439
# Computing AUC...
# AUC test: 0.6774698721477947
# Computing AUC...
# AUC test: 0.6751575212577231
# Computing AUC...
# AUC test: 0.6785465222976693
# Computing AUC...
# AUC test: 0.6777145653636752
# Computing AUC...
# AUC test: 0.6790236740686364
# Computing AUC...
# AUC test: 0.6762708753899798
# Computing AUC...
# AUC test: 0.6757570196366306
# Computing AUC...
# AUC test: 0.6762708753899798
# Computing AUC...
# AUC test: 0.6760017128525112
# Computing AUC...
# AUC test: 0.678815684835138
# Computing AUC...
# AUC test: 0.678399706368141
# Computing AUC...
# AUC test: 0.6746069615219918
# Computing AUC...
# AUC test: 0.6777268000244693
# Computing AUC...
# AUC test: 0.6774821068085888
# Computing AUC...
# AUC test: 0.6768703737688873
# Computing AUC...
# AUC test: 0.6762219367468036
# Computing AUC...
# AUC test: 0.6780571358659081
# Computing AUC...
# AUC test: 0.6790481433902245
# Computing AUC...
# AUC test: 0.6776533920597051

# %%
'''uFactorsCopy = uFactors * 1.0
rFactorsCopy = rFactors * 1.0'''
hybrid = BPR(interactions_tr, interactions_te, False, P=uFactors, Q=rFactors, alpha=0.01, _lambda=0.01, K=30, prob=False, _pop=False, _iter = 50*10**6)
# Out:
# BPR with K: 30
# Computing AUC...
# AUC test: 0.8400318101180645
# Computing AUC...
# AUC test: 0.8396403009726555
# Computing AUC...
# AUC test: 0.8387961093778675
# Computing AUC...
# AUC test: 0.842747904814339
# Computing AUC...
# AUC test: 0.840239799351563
# Computing AUC...
# AUC test: 0.8419893558451091
# Computing AUC...
# AUC test: 0.8420505291490793
# Computing AUC...
# AUC test: 0.8407047164617361
# Computing AUC...
# AUC test: 0.8413653881446137
# Computing AUC...
# AUC test: 0.8415366733957301
# Computing AUC...
# AUC test: 0.8422340490609898
# Computing AUC...
# AUC test: 0.8431027099773659
# Computing AUC...
# AUC test: 0.8421484064354315
# Computing AUC...
# AUC test: 0.8423808649905181
# Computing AUC...
# AUC test: 0.8436532697130972
# Computing AUC...
# AUC test: 0.8413653881446137
# Computing AUC...
# AUC test: 0.8423074570257539
# Computing AUC...
# AUC test: 0.8413776228054077
# Computing AUC...
# AUC test: 0.8423808649905181
# Computing AUC...
# AUC test: 0.8426010888848107
# Computing AUC...
# AUC test: 0.8404600232458556
# Computing AUC...
# AUC test: 0.8430782406557779
# Computing AUC...
# AUC test: 0.8417936012724048
# Computing AUC...
# AUC test: 0.8424665076160763
# Computing AUC...
# AUC test: 0.8425643849024286
# Computing AUC...
# AUC test: 0.8420505291490793
# Computing AUC...
# AUC test: 0.8411206949287331
# Computing AUC...
# AUC test: 0.8432128219245122
# Computing AUC...
# AUC test: 0.8440814828408882
# Computing AUC...
# AUC test: 0.842723435492751
# Computing AUC...
# AUC test: 0.8442160641096226
# Computing AUC...
# AUC test: 0.843604331069921
# Computing AUC...
# AUC test: 0.8435431577659509
# Computing AUC...
# AUC test: 0.8425766195632226
# Computing AUC...
# AUC test: 0.8459656206031688
# Computing AUC...
# AUC test: 0.8433718725148345
# Computing AUC...
# AUC test: 0.8465528843212822
# Computing AUC...
# AUC test: 0.8436288003915091
# Computing AUC...
# AUC test: 0.8413409188230256
# Computing AUC...
# AUC test: 0.8423808649905181
# Computing AUC...
# AUC test: 0.8425888542240166
# Computing AUC...
# AUC test: 0.8424787422768704
# Computing AUC...
# AUC test: 0.8442650027527987
# Computing AUC...
# AUC test: 0.8455863461185539
# Computing AUC...
# AUC test: 0.8438734936073897
# Computing AUC...
# AUC test: 0.8437878509818315
# Computing AUC...
# AUC test: 0.843151648620542
# Computing AUC...
# AUC test: 0.8451948369731449
# Computing AUC...
# AUC test: 0.8455007034929957
# Computing AUC...
# AUC test: 0.8429558940478376
# Computing AUC...
# AUC test: 0.8447666238453538
# Computing AUC...
# AUC test: 0.842747904814339
# Computing AUC...
# AUC test: 0.8461002018719032
# Computing AUC...
# AUC test: 0.8446687465590017
# Computing AUC...
# AUC test: 0.8441793601272405
# Computing AUC...
# AUC test: 0.8450113170612344
# Computing AUC...
# AUC test: 0.8431883526029241
# Computing AUC...
# AUC test: 0.8457209273872882
# Computing AUC...
# AUC test: 0.8434452804795987
# Computing AUC...
# AUC test: 0.8465528843212822
# Computing AUC...
# AUC test: 0.8437266776778614
# Computing AUC...
# AUC test: 0.8447666238453538
# Computing AUC...
# AUC test: 0.8455618767969658
# Computing AUC...
# AUC test: 0.8445341652902674
# Computing AUC...
# AUC test: 0.8423074570257539
# Computing AUC...
# AUC test: 0.8434819844619807
# Computing AUC...
# AUC test: 0.8433841071756285
# Computing AUC...
# AUC test: 0.8448033278277359
# Computing AUC...
# AUC test: 0.846467241695724
# Computing AUC...
# AUC test: 0.8466507616076344
# Computing AUC...
# AUC test: 0.8459166819599927
# Computing AUC...
# AUC test: 0.8463571297485777
# Computing AUC...
# AUC test: 0.8451336636691748
# Computing AUC...
# AUC test: 0.8430537713341898
# Computing AUC...
# AUC test: 0.8457821006912584
# Computing AUC...
# AUC test: 0.844840031810118
# Computing AUC...
# AUC test: 0.8462837217838135
# Computing AUC...
# AUC test: 0.845231540955527
# Computing AUC...
# AUC test: 0.8465406496604881
# Computing AUC...
# AUC test: 0.8445586346118554
# Computing AUC...
# AUC test: 0.8467731082155747
# Computing AUC...
# AUC test: 0.844852266470912
# Computing AUC...
# AUC test: 0.8461369058542851
# Computing AUC...
# AUC test: 0.8459411512815808
# Computing AUC...
# AUC test: 0.8463081911054016
# Computing AUC...
# AUC test: 0.8447054505413838
# Computing AUC...
# AUC test: 0.8478008197222732
# Computing AUC...
# AUC test: 0.8459900899247569
# Computing AUC...
# AUC test: 0.8461369058542851
# Computing AUC...
# AUC test: 0.8472380253257479
# Computing AUC...
# AUC test: 0.8464060683917538
# Computing AUC...
# AUC test: 0.8459778552639629
# Computing AUC...
# AUC test: 0.8453661222242613
# Computing AUC...
# AUC test: 0.846503945678106
# Computing AUC...
# AUC test: 0.8468342815195449
# Computing AUC...
# AUC test: 0.8465895883036643
# Computing AUC...
# AUC test: 0.8486450113170613
# Computing AUC...
# AUC test: 0.8464427723741359
# Computing AUC...
# AUC test: 0.8469566281274852
# Computing AUC...
# AUC test: 0.8474582492200404
# Computing AUC...
# AUC test: 0.8459166819599927

# %%
simple = BPR(interactions_tr, interactions_te, False, alpha=0.05, _lambda=0.01, K=30, prob=False, _pop=False, _iter = 50*10**6)
# Out:
# BPR with K: 30
# Computing AUC...
# AUC test: 0.49740013458126875
# Computing AUC...
# AUC test: 0.4996513121673702
# Computing AUC...
# AUC test: 0.5039823820884566
# Computing AUC...
# AUC test: 0.5231418608919067
# Computing AUC...
# AUC test: 0.5931730592769315
# Computing AUC...
# AUC test: 0.6827185416284334
# Computing AUC...
# AUC test: 0.7491527497400134
# Computing AUC...
# AUC test: 0.7862482412675108
# Computing AUC...
# AUC test: 0.8091025876307579
# Computing AUC...
# AUC test: 0.8195632226096532
# Computing AUC...
# AUC test: 0.8258885422401664
# Computing AUC...
# AUC test: 0.8287759221875574
# Computing AUC...
# AUC test: 0.833192634734202
# Computing AUC...
# AUC test: 0.8338166024346975
# Computing AUC...
# AUC test: 0.83403682632899
# Computing AUC...
# AUC test: 0.8348810179237781
# Computing AUC...
# AUC test: 0.8365571664525601
# Computing AUC...
# AUC test: 0.8366795130605004
# Computing AUC...
# AUC test: 0.8366550437389123
# Computing AUC...
# AUC test: 0.83731571542179
# Computing AUC...
# AUC test: 0.8392977304704227
# Computing AUC...
# AUC test: 0.8372545421178198
# Computing AUC...
# AUC test: 0.8369609102587631
# Computing AUC...
# AUC test: 0.8383923655716645
# Computing AUC...
# AUC test: 0.8381599070165779
# Computing AUC...
# AUC test: 0.8396647702942436
# Computing AUC...
# AUC test: 0.8393344344528048
# Computing AUC...
# AUC test: 0.8397993515629779
# Computing AUC...
# AUC test: 0.8408760017128525
# Computing AUC...
# AUC test: 0.8408025937480883
# Computing AUC...
# AUC test: 0.8427846087967211
# Computing AUC...
# AUC test: 0.8413898574662018
# Computing AUC...
# AUC test: 0.8420382944882853
# Computing AUC...
# AUC test: 0.8416712546644645
# Computing AUC...
# AUC test: 0.8411329295895271
# Computing AUC...
# AUC test: 0.8411573989111152
# Computing AUC...
# AUC test: 0.8409004710344405
# Computing AUC...
# AUC test: 0.841487734752554
# Computing AUC...
# AUC test: 0.8395179543647152
# Computing AUC...
# AUC test: 0.8408882363736465
# Computing AUC...
# AUC test: 0.8430170673518077
# Computing AUC...
# AUC test: 0.8429069554046614
# Computing AUC...
# AUC test: 0.8424298036336942
# Computing AUC...
# AUC test: 0.8424298036336942
# Computing AUC...
# AUC test: 0.8444362880039151
# Computing AUC...
# AUC test: 0.841879243897963
# Computing AUC...
# AUC test: 0.8416712546644645
# Computing AUC...
# AUC test: 0.8432862298892764
# Computing AUC...
# AUC test: 0.8449256744356762
# Computing AUC...
# AUC test: 0.8429558940478376
# Computing AUC...
# AUC test: 0.8432984645500704
# Computing AUC...
# AUC test: 0.8453171835810852
# Computing AUC...
# AUC test: 0.8421117024530494
# Computing AUC...
# AUC test: 0.8434330458188046
# Computing AUC...
# AUC test: 0.8437389123386554
# Computing AUC...
# AUC test: 0.843127179298954
# Computing AUC...
# AUC test: 0.8434575151403927
# Computing AUC...
# AUC test: 0.8438490242858017
# Computing AUC...
# AUC test: 0.8431638832813361
# Computing AUC...
# AUC test: 0.8442038294488285
# Computing AUC...
# AUC test: 0.8462225484798434
# Computing AUC...
# AUC test: 0.8436532697130972
# Computing AUC...
# AUC test: 0.8450113170612344
# Computing AUC...
# AUC test: 0.8466997002508105
# Computing AUC...
# AUC test: 0.8431883526029241
# Computing AUC...
# AUC test: 0.8424665076160763
# Computing AUC...
# AUC test: 0.8442527680920047
# Computing AUC...
# AUC test: 0.8470789747354255
# Computing AUC...
# AUC test: 0.8456842234049061
# Computing AUC...
# AUC test: 0.8445831039334435
# Computing AUC...
# AUC test: 0.8451948369731449
# Computing AUC...
# AUC test: 0.845623050100936
# Computing AUC...
# AUC test: 0.8448889704532941
# Computing AUC...
# AUC test: 0.8450113170612344
# Computing AUC...
# AUC test: 0.8450480210436165
# Computing AUC...
# AUC test: 0.844852266470912
# Computing AUC...
# AUC test: 0.8465284149996941
# Computing AUC...
# AUC test: 0.8449623784180583
# Computing AUC...
# AUC test: 0.8461124365326971
# Computing AUC...
# AUC test: 0.8453783568850554
# Computing AUC...
# AUC test: 0.8451458983299688
# Computing AUC...
# AUC test: 0.8448767357925001
# Computing AUC...
# AUC test: 0.8484125527619747
# Computing AUC...
# AUC test: 0.8461736098366672
# Computing AUC...
# AUC test: 0.8453783568850554
# Computing AUC...
# AUC test: 0.8471401480393956
# Computing AUC...
# AUC test: 0.8453661222242613
# Computing AUC...
# AUC test: 0.8445219306294733
# Computing AUC...
# AUC test: 0.844852266470912
# Computing AUC...
# AUC test: 0.8450969596867927
# Computing AUC...
# AUC test: 0.8463693644093717
# Computing AUC...
# AUC test: 0.8465406496604881
# Computing AUC...
# AUC test: 0.844375114699945
# Computing AUC...
# AUC test: 0.8465161803389001
# Computing AUC...
# AUC test: 0.8460757325503151
# Computing AUC...
# AUC test: 0.8452804795987031
# Computing AUC...
# AUC test: 0.8450480210436165
# Computing AUC...
# AUC test: 0.8480210436165657
# Computing AUC...
# AUC test: 0.8471768520217777
# Computing AUC...
# AUC test: 0.8462959564446075
# Computing AUC...
# AUC test: 0.8442527680920047

# %%
with sns.plotting_context("notebook", font_scale=2):
    simpleBPR_AUC = pd.Series(simple[1])
    simpleBPR_AUC.name = "AUC"
    plotAUC(simpleBPR_AUC, 500000, "Simple BPR AUC")

# %%
bias = BPR(interactions_tr, interactions_te, True, alpha=0.02, _lambda=0.01, K=30, prob=False, _pop=False, _iter = 50*10**6)
# Out:
# BPR with K: 30
# Computing AUC...
# AUC test: 0.5000917599559552
# Computing AUC...
# AUC test: 0.8235394873677128
# Computing AUC...
# AUC test: 0.8312840276503334
# Computing AUC...
# AUC test: 0.8365082278093839
# Computing AUC...
# AUC test: 0.836911971615587
# Computing AUC...
# AUC test: 0.8381599070165779
# Computing AUC...
# AUC test: 0.839420077078363
# Computing AUC...
# AUC test: 0.839420077078363
# Computing AUC...
# AUC test: 0.8397504129198018
# Computing AUC...
# AUC test: 0.8390897412369243
# Computing AUC...
# AUC test: 0.8396892396158316
# Computing AUC...
# AUC test: 0.8399584021533003
# Computing AUC...
# AUC test: 0.8393589037743928
# Computing AUC...
# AUC test: 0.8400195754572705
# Computing AUC...
# AUC test: 0.8401908607083869
# Computing AUC...
# AUC test: 0.8416712546644645
# Computing AUC...
# AUC test: 0.841952651862727
# Computing AUC...
# AUC test: 0.8417936012724048
# Computing AUC...
# AUC test: 0.8422218144001957
# Computing AUC...
# AUC test: 0.8400807487612406
# Computing AUC...
# AUC test: 0.8418058359331988
# Computing AUC...
# AUC test: 0.8393711384351868
# Computing AUC...
# AUC test: 0.8401663913867988
# Computing AUC...
# AUC test: 0.8395057197039212
# Computing AUC...
# AUC test: 0.8407291857833241
# Computing AUC...
# AUC test: 0.8413164495014376
# Computing AUC...
# AUC test: 0.8415489080565242
# Computing AUC...
# AUC test: 0.8392365571664525
# Computing AUC...
# AUC test: 0.8393099651312167
# Computing AUC...
# AUC test: 0.8416834893252585
# Computing AUC...
# AUC test: 0.8398727595277421
# Computing AUC...
# AUC test: 0.8408148284088823
# Computing AUC...
# AUC test: 0.8416467853428764
# Computing AUC...
# AUC test: 0.8403866152810914
# Computing AUC...
# AUC test: 0.8411573989111152
# Computing AUC...
# AUC test: 0.8416834893252585
# Computing AUC...
# AUC test: 0.8387227014131033
# Computing AUC...
# AUC test: 0.8411206949287331
# Computing AUC...
# AUC test: 0.8405089618890317
# Computing AUC...
# AUC test: 0.8409004710344405
# Computing AUC...
# AUC test: 0.8395668930078913
# Computing AUC...
# AUC test: 0.8409004710344405
# Computing AUC...
# AUC test: 0.8403009726555332
# Computing AUC...
# AUC test: 0.8382944882853123
# Computing AUC...
# AUC test: 0.8411818682327032
# Computing AUC...
# AUC test: 0.8402030953691809
# Computing AUC...
# AUC test: 0.8386982320915153
# Computing AUC...
# AUC test: 0.8409983483207928
# Computing AUC...
# AUC test: 0.8412675108582615
# Computing AUC...
# AUC test: 0.8414265614485839
# Computing AUC...
# AUC test: 0.8399461674925063
# Computing AUC...
# AUC test: 0.8424665076160763
# Computing AUC...
# AUC test: 0.8416712546644645
# Computing AUC...
# AUC test: 0.8388205786994556
# Computing AUC...
# AUC test: 0.8415856120389063
# Computing AUC...
# AUC test: 0.8411206949287331
# Computing AUC...
# AUC test: 0.8405579005322077
# Computing AUC...
# AUC test: 0.8410350523031749
# Computing AUC...
# AUC test: 0.8433841071756285
# Computing AUC...
# AUC test: 0.8397014742766257
# Computing AUC...
# AUC test: 0.8400195754572705
# Computing AUC...
# AUC test: 0.8422340490609898
# Computing AUC...
# AUC test: 0.8407903590872943
# Computing AUC...
# AUC test: 0.8426744968495749
# Computing AUC...
# AUC test: 0.8412919801798495
# Computing AUC...
# AUC test: 0.8438245549642136
# Computing AUC...
# AUC test: 0.8412675108582615
# Computing AUC...
# AUC test: 0.8434085764972166
# Computing AUC...
# AUC test: 0.8433718725148345
# Computing AUC...
# AUC test: 0.8411329295895271
# Computing AUC...
# AUC test: 0.8414143267877898
# Computing AUC...
# AUC test: 0.8423074570257539
# Computing AUC...
# AUC test: 0.8415489080565242
# Computing AUC...
# AUC test: 0.8416100813604943
# Computing AUC...
# AUC test: 0.8404844925674436
# Computing AUC...
# AUC test: 0.8411696335719092
# Computing AUC...
# AUC test: 0.8413776228054077
# Computing AUC...
# AUC test: 0.8425154462592525
# Computing AUC...
# AUC test: 0.8413653881446137
# Computing AUC...
# AUC test: 0.8422829877041659
# Computing AUC...
# AUC test: 0.8428335474398972
# Computing AUC...
# AUC test: 0.8408025937480883
# Computing AUC...
# AUC test: 0.8420260598274912
# Computing AUC...
# AUC test: 0.8399951061356824
# Computing AUC...
# AUC test: 0.8449012051140882
# Computing AUC...
# AUC test: 0.8422462837217838
# Computing AUC...
# AUC test: 0.8432495259068943
# Computing AUC...
# AUC test: 0.8420749984706674
# Computing AUC...
# AUC test: 0.8422707530433718
# Computing AUC...
# AUC test: 0.8402765033339451
# Computing AUC...
# AUC test: 0.8412185722150853
# Computing AUC...
# AUC test: 0.8434942191227748
# Computing AUC...
# AUC test: 0.8445953385942375
# Computing AUC...
# AUC test: 0.8417324279684346
# Computing AUC...
# AUC test: 0.8433841071756285
# Computing AUC...
# AUC test: 0.8423930996513121
# Computing AUC...
# AUC test: 0.841891478558757
# Computing AUC...
# AUC test: 0.8407414204441181
# Computing AUC...
# AUC test: 0.8425643849024286
# Computing AUC...
# AUC test: 0.8427601394751331
# Computing AUC...
# AUC test: 0.8418303052547869

# %%
with sns.plotting_context("notebook", font_scale=2):
    biasBPR_AUC = pd.Series(bias[1])
    biasBPR_AUC.name = "AUC"
    plotAUC(biasBPR_AUC, 500000, "Bias BPR AUC")

# %%
_0_75_ = BPR(interactions_tr, interactions_te, False, alpha=0.02, _lambda=0.01, K=30, prob=True, power=0.75, _iter = 50*10**6)
# Out:
# BPR with K: 30
# done
# Computing AUC...
# AUC test: 0.5002508105462776
# Computing AUC...
# AUC test: 0.5001651679207194
# Computing AUC...
# AUC test: 0.5036520462470178
# Computing AUC...
# AUC test: 0.49998164800880895
# Computing AUC...
# AUC test: 0.5005933810485105
# Computing AUC...
# AUC test: 0.5018046124671194
# Computing AUC...
# AUC test: 0.5034073530311373
# Computing AUC...
# AUC test: 0.502098244326176
# Computing AUC...
# AUC test: 0.5028078546522298
# Computing AUC...
# AUC test: 0.5034685263351074
# Computing AUC...
# AUC test: 0.5042882486083073
# Computing AUC...
# AUC test: 0.5104300483269102
# Computing AUC...
# AUC test: 0.5160212883097816
# Computing AUC...
# AUC test: 0.5215024163455069
# Computing AUC...
# AUC test: 0.5310699210864379
# Computing AUC...
# AUC test: 0.540649660488163
# Computing AUC...
# AUC test: 0.5579739401725087
# Computing AUC...
# AUC test: 0.5775249281213678
# Computing AUC...
# AUC test: 0.6014681592952835
# Computing AUC...
# AUC test: 0.6265002752798678
# Computing AUC...
# AUC test: 0.6494035602862911
# Computing AUC...
# AUC test: 0.675524561081544
# Computing AUC...
# AUC test: 0.6973144919557105
# Computing AUC...
# AUC test: 0.717403804979507
# Computing AUC...
# AUC test: 0.7362207132807242
# Computing AUC...
# AUC test: 0.753924267449685
# Computing AUC...
# AUC test: 0.7626108766134458
# Computing AUC...
# AUC test: 0.7781733651434514
# Computing AUC...
# AUC test: 0.7847556126506393
# Computing AUC...
# AUC test: 0.7931730592769316
# Computing AUC...
# AUC test: 0.7986419526518628
# Computing AUC...
# AUC test: 0.8018351991191044
# Computing AUC...
# AUC test: 0.8059093411635162
# Computing AUC...
# AUC test: 0.8108643787850982
# Computing AUC...
# AUC test: 0.8122101914724414
# Computing AUC...
# AUC test: 0.8154156726004772
# Computing AUC...
# AUC test: 0.8177035541689607
# Computing AUC...
# AUC test: 0.8181929406007219
# Computing AUC...
# AUC test: 0.8209090352969964
# Computing AUC...
# AUC test: 0.8209946779225546
# Computing AUC...
# AUC test: 0.8237107726188292
# Computing AUC...
# AUC test: 0.8246406068391754
# Computing AUC...
# AUC test: 0.8257906649538141
# Computing AUC...
# AUC test: 0.8245794335352052
# Computing AUC...
# AUC test: 0.8253624518260231
# Computing AUC...
# AUC test: 0.8266837951917783
# Computing AUC...
# AUC test: 0.8275035174649783
# Computing AUC...
# AUC test: 0.8278338533064171
# Computing AUC...
# AUC test: 0.8278460879672112
# Computing AUC...
# AUC test: 0.8273567015354499
# Computing AUC...
# AUC test: 0.8289594420994678
# Computing AUC...
# AUC test: 0.8279317305927694
# Computing AUC...
# AUC test: 0.8281152505046797
# Computing AUC...
# AUC test: 0.8305254786811036
# Computing AUC...
# AUC test: 0.8293387165840828
# Computing AUC...
# AUC test: 0.829485532513611
# Computing AUC...
# AUC test: 0.8305866519850738
# Computing AUC...
# AUC test: 0.8305866519850738
# Computing AUC...
# AUC test: 0.8292286046369365
# Computing AUC...
# AUC test: 0.8317489447605065
# Computing AUC...
# AUC test: 0.8324585550865602
# Computing AUC...
# AUC test: 0.8318223527252707
# Computing AUC...
# AUC test: 0.8306478252890439
# Computing AUC...
# AUC test: 0.8315042515446259
# Computing AUC...
# AUC test: 0.8316755367957424
# Computing AUC...
# AUC test: 0.8325319630513244
# Computing AUC...
# AUC test: 0.8313819049366856
# Computing AUC...
# AUC test: 0.8313084969719214
# Computing AUC...
# AUC test: 0.8307457025753961
# Computing AUC...
# AUC test: 0.8325686670337065
# Computing AUC...
# AUC test: 0.8327399522848229
# Computing AUC...
# AUC test: 0.8329846455007035
# Computing AUC...
# AUC test: 0.8332538080381722
# Computing AUC...
# AUC test: 0.8304031320731633
# Computing AUC...
# AUC test: 0.8315776595093901
# Computing AUC...
# AUC test: 0.8332293387165841
# Computing AUC...
# AUC test: 0.8318957606900349
# Computing AUC...
# AUC test: 0.8348687832629841
# Computing AUC...
# AUC test: 0.831553190187802
# Computing AUC...
# AUC test: 0.8333516853245244
# Computing AUC...
# AUC test: 0.8323239738178259
# Computing AUC...
# AUC test: 0.8305866519850738
# Computing AUC...
# AUC test: 0.8345139780999572
# Computing AUC...
# AUC test: 0.8317367100997125
# Computing AUC...
# AUC test: 0.8328745335535572
# Computing AUC...
# AUC test: 0.8341102342937542
# Computing AUC...
# AUC test: 0.8360066067168288
# Computing AUC...
# AUC test: 0.8326176056768826
# Computing AUC...
# AUC test: 0.834440570135193
# Computing AUC...
# AUC test: 0.8351868844436288
# Computing AUC...
# AUC test: 0.8334617972716707
# Computing AUC...
# AUC test: 0.8334128586284946
# Computing AUC...
# AUC test: 0.8354682816418915
# Computing AUC...
# AUC test: 0.8343916314920169
# Computing AUC...
# AUC test: 0.8334373279500826
# Computing AUC...
# AUC test: 0.8351012418180705
# Computing AUC...
# AUC test: 0.8329601761791154
# Computing AUC...
# AUC test: 0.8363491772190617
# Computing AUC...
# AUC test: 0.8346852633510736
# Computing AUC...
# AUC test: 0.8346485593686915
# Computing AUC...
# AUC test: 0.8331559307518199

# %%
_0_875_ = BPR(interactions_tr, interactions_te, False, alpha=0.02, _lambda=0.01, K=30, prob=True, power=0.875, _iter = 50*10**6)
# Out:
# BPR with K: 30
# done
# Computing AUC...
# AUC test: 0.49861136599987765
# Computing AUC...
# AUC test: 0.5010093595155074
# Computing AUC...
# AUC test: 0.49985930140086865
# Computing AUC...
# AUC test: 0.5009359515507432
# Computing AUC...
# AUC test: 0.5016945005199731
# Computing AUC...
# AUC test: 0.5044962378418059
# Computing AUC...
# AUC test: 0.4990518137884627
# Computing AUC...
# AUC test: 0.5051569095246834
# Computing AUC...
# AUC test: 0.5059399278155013
# Computing AUC...
# AUC test: 0.5089618890316266
# Computing AUC...
# AUC test: 0.5142472624946474
# Computing AUC...
# AUC test: 0.5231296262311127
# Computing AUC...
# AUC test: 0.5344833914479721
# Computing AUC...
# AUC test: 0.5501437572643298
# Computing AUC...
# AUC test: 0.571786872208968
# Computing AUC...
# AUC test: 0.5988132379029791
# Computing AUC...
# AUC test: 0.62571725698905
# Computing AUC...
# AUC test: 0.6530127852205297
# Computing AUC...
# AUC test: 0.6827307762892274
# Computing AUC...
# AUC test: 0.7072123325380804
# Computing AUC...
# AUC test: 0.7260170061785037
# Computing AUC...
# AUC test: 0.74686486817153
# Computing AUC...
# AUC test: 0.7642380864990518
# Computing AUC...
# AUC test: 0.7786015782712424
# Computing AUC...
# AUC test: 0.7873371260781795
# Computing AUC...
# AUC test: 0.7977855263962806
# Computing AUC...
# AUC test: 0.8040007340796477
# Computing AUC...
# AUC test: 0.8078424175689729
# Computing AUC...
# AUC test: 0.8126873432434085
# Computing AUC...
# AUC test: 0.8180094206888114
# Computing AUC...
# AUC test: 0.818682327032483
# Computing AUC...
# AUC test: 0.8197345078607695
# Computing AUC...
# AUC test: 0.8225117758610142
# Computing AUC...
# AUC test: 0.825325747843641
# Computing AUC...
# AUC test: 0.8281152505046797
# Computing AUC...
# AUC test: 0.8299259803021961
# Computing AUC...
# AUC test: 0.8288493301523215
# Computing AUC...
# AUC test: 0.828213127791032
# Computing AUC...
# AUC test: 0.8291184926897902
# Computing AUC...
# AUC test: 0.8304276013947514
# Computing AUC...
# AUC test: 0.8309659264696886
# Computing AUC...
# AUC test: 0.8309781611304826
# Computing AUC...
# AUC test: 0.8321282192451215
# Computing AUC...
# AUC test: 0.8311005077384229
# Computing AUC...
# AUC test: 0.8311861503639811
# Computing AUC...
# AUC test: 0.8332293387165841
# Computing AUC...
# AUC test: 0.8322260965314736
# Computing AUC...
# AUC test: 0.8318468220468588
# Computing AUC...
# AUC test: 0.8354315776595094
# Computing AUC...
# AUC test: 0.8343671621704288
# Computing AUC...
# AUC test: 0.8337554291307273
# Computing AUC...
# AUC test: 0.8326787789808527
# Computing AUC...
# AUC test: 0.8345629167431333
# Computing AUC...
# AUC test: 0.8344650394567811
# Computing AUC...
# AUC test: 0.8334250932892886
# Computing AUC...
# AUC test: 0.8345629167431333
# Computing AUC...
# AUC test: 0.8360433106992109
# Computing AUC...
# AUC test: 0.8351134764788646
# Computing AUC...
# AUC test: 0.833620847861993
# Computing AUC...
# AUC test: 0.8346730286902796
# Computing AUC...
# AUC test: 0.8361289533247691
# Computing AUC...
# AUC test: 0.8360066067168288
# Computing AUC...
# AUC test: 0.835688505536184
# Computing AUC...
# AUC test: 0.8359454334128587
# Computing AUC...
# AUC test: 0.8363736465406496
# Computing AUC...
# AUC test: 0.8363002385758855
# Computing AUC...
# AUC test: 0.8350767724964825
# Computing AUC...
# AUC test: 0.8361411879855631
# Computing AUC...
# AUC test: 0.8344650394567811
# Computing AUC...
# AUC test: 0.8362512999327094
# Computing AUC...
# AUC test: 0.8374013580473482
# Computing AUC...
# AUC test: 0.8352358230868049
# Computing AUC...
# AUC test: 0.8341224689545482
# Computing AUC...
# AUC test: 0.8375237046552885
# Computing AUC...
# AUC test: 0.8362268306111214
# Computing AUC...
# AUC test: 0.8357619135009482
# Computing AUC...
# AUC test: 0.8371933688138496
# Computing AUC...
# AUC test: 0.8387104667523093
# Computing AUC...
# AUC test: 0.8367773903468526
# Computing AUC...
# AUC test: 0.8361167186639751
# Computing AUC...
# AUC test: 0.8376338166024347
# Computing AUC...
# AUC test: 0.8367773903468526
# Computing AUC...
# AUC test: 0.8355416896066556
# Computing AUC...
# AUC test: 0.8391876185232764
# Computing AUC...
# AUC test: 0.836080014681593
# Computing AUC...
# AUC test: 0.8369731449195571
# Computing AUC...
# AUC test: 0.8365816357741481
# Computing AUC...
# AUC test: 0.8375359393160825
# Computing AUC...
# AUC test: 0.8373768887257601
# Computing AUC...
# AUC test: 0.8374502966905243
# Computing AUC...
# AUC test: 0.8376949899064049
# Computing AUC...
# AUC test: 0.8365082278093839
# Computing AUC...
# AUC test: 0.8395179543647152
# Computing AUC...
# AUC test: 0.8388695173426317
# Computing AUC...
# AUC test: 0.8383678962500765
# Computing AUC...
# AUC test: 0.8369853795803511
# Computing AUC...
# AUC test: 0.8363369425582676
# Computing AUC...
# AUC test: 0.838967394628984
# Computing AUC...
# AUC test: 0.8378785098183152
# Computing AUC...
# AUC test: 0.8376215819416407
# Computing AUC...
# AUC test: 0.838967394628984

# %%
normalfails = bias[0]

# %%
nobiasnormalfails = simple[0]

# %%
nobiasnormal_0_75_fails = _0_75_[0]

# %%
nobiasnormal_0_875_fails = _0_875_[0]

# %% [markdown]
# # Grid search

# %%
ks = [30, 50, 70]
lambdas = [0.01, 0.025, 0.05]

results = []
i = 0

for k in ks:
    results.append([])
    for _lambda in lambdas:
        results[i].append(BPR(interactions_tr, interactions_te, False, 0.01, K = k, _lambda = _lambda, prob=True, power=0.875, _iter = 50*10**6))
    i += 1
# Out:
# BPR with K: 30
# done
# Computing AUC...
# AUC test: 0.5007846963013234
# Computing AUC...
# AUC test: 0.4983987953851374
# Computing AUC...
# AUC test: 0.5005302002035968
# Computing AUC...
# AUC test: 0.4996712758737699
# Computing AUC...
# AUC test: 0.498812351543943
# Computing AUC...
# AUC test: 0.5002863081099423
# Computing AUC...
# AUC test: 0.5004559721750933
# Computing AUC...
# AUC test: 0.5007104682728198
# Computing AUC...
# AUC test: 0.5005832202239565
# Computing AUC...
# AUC test: 0.5017284526637258
# Computing AUC...
# AUC test: 0.5007422802850356
# Computing AUC...
# AUC test: 0.5000424160162877
# Computing AUC...
# AUC test: 0.5012936884967764
# Computing AUC...
# AUC test: 0.49896080760095013
# Computing AUC...
# AUC test: 0.5027676450627757
# Computing AUC...
# AUC test: 0.5034038853070919
# Computing AUC...
# AUC test: 0.5002969121140143
# Computing AUC...
# AUC test: 0.501876908720733
# Computing AUC...
# AUC test: 0.5018026806922293
# Computing AUC...
# AUC test: 0.501686036647438
# Computing AUC...
# AUC test: 0.5015799966067187
# Computing AUC...
# AUC test: 0.5039765015269766
# Computing AUC...
# AUC test: 0.5038068374618256
# Computing AUC...
# AUC test: 0.5025661689854088
# Computing AUC...
# AUC test: 0.5047081778079403
# Computing AUC...
# AUC test: 0.5054716661011198
# Computing AUC...
# AUC test: 0.5082711231761113
# Computing AUC...
# AUC test: 0.5063730064472345
# Computing AUC...
# AUC test: 0.5097768917543264
# Computing AUC...
# AUC test: 0.5095966236851035
# Computing AUC...
# AUC test: 0.515630302002036
# Computing AUC...
# AUC test: 0.5165846623685103
# Computing AUC...
# AUC test: 0.5183131150322362
# Computing AUC...
# AUC test: 0.5222153885307091
# Computing AUC...
# AUC test: 0.5260858500169664
# Computing AUC...
# AUC test: 0.5322149643705463
# Computing AUC...
# AUC test: 0.5378138785205293
# Computing AUC...
# AUC test: 0.540931455717679
# Computing AUC...
# AUC test: 0.5473892941974889
# Computing AUC...
# AUC test: 0.5547272650152698
# Computing AUC...
# AUC test: 0.5617365117068205
# Computing AUC...
# AUC test: 0.5688411944350187
# Computing AUC...
# AUC test: 0.5783423820834748
# Computing AUC...
# AUC test: 0.5864862572107228
# Computing AUC...
# AUC test: 0.5972493213437394
# Computing AUC...
# AUC test: 0.607842721411605
# Computing AUC...
# AUC test: 0.615318544282321
# Computing AUC...
# AUC test: 0.6284993213437394
# Computing AUC...
# AUC test: 0.6358054801493044
# Computing AUC...
# AUC test: 0.6468866644044792
# Computing AUC...
# AUC test: 0.657448252460129
# Computing AUC...
# AUC test: 0.6667267560230743
# Computing AUC...
# AUC test: 0.6778927723108246
# Computing AUC...
# AUC test: 0.6886452324397693
# Computing AUC...
# AUC test: 0.6947425347811333
# Computing AUC...
# AUC test: 0.7059721750933152
# Computing AUC...
# AUC test: 0.7139145741431965
# Computing AUC...
# AUC test: 0.7206375127248049
# Computing AUC...
# AUC test: 0.7290252799457075
# Computing AUC...
# AUC test: 0.7366601628775026
# Computing AUC...
# AUC test: 0.7414425687139464
# Computing AUC...
# AUC test: 0.7463628266033254
# Computing AUC...
# AUC test: 0.7542309976247031
# Computing AUC...
# AUC test: 0.7596602477095351
# Computing AUC...
# AUC test: 0.7622582287071599
# Computing AUC...
# AUC test: 0.7706141839158466
# Computing AUC...
# AUC test: 0.7719714964370546
# Computing AUC...
# AUC test: 0.7753965897522904
# Computing AUC...
# AUC test: 0.7809424838819138
# Computing AUC...
# AUC test: 0.7833708008143875
# Computing AUC...
# AUC test: 0.7855658296572786
# Computing AUC...
# AUC test: 0.7906027315914489
# Computing AUC...
# AUC test: 0.7928189684424839
# Computing AUC...
# AUC test: 0.7932643366135053
# Computing AUC...
# AUC test: 0.7975059382422803
# Computing AUC...
# AUC test: 0.7979619104173736
# Computing AUC...
# AUC test: 0.799944859178826
# Computing AUC...
# AUC test: 0.8018853919239906
# Computing AUC...
# AUC test: 0.803825924669155
# Computing AUC...
# AUC test: 0.8048863250763488
# Computing AUC...
# AUC test: 0.8045045809297591
# Computing AUC...
# AUC test: 0.8061694095690533
# Computing AUC...
# AUC test: 0.8079508822531388
# Computing AUC...
# AUC test: 0.8088946386155412
# Computing AUC...
# AUC test: 0.8094248388191381
# Computing AUC...
# AUC test: 0.8092021547336274
# Computing AUC...
# AUC test: 0.8085659144893111
# Computing AUC...
# AUC test: 0.8119697997964032
# Computing AUC...
# AUC test: 0.812659060061079
# Computing AUC...
# AUC test: 0.8123939599592807
# Computing AUC...
# AUC test: 0.812659060061079
# Computing AUC...
# AUC test: 0.8159993213437394
# Computing AUC...
# AUC test: 0.8131680522565321
# Computing AUC...
# AUC test: 0.815734221241941
# Computing AUC...
# AUC test: 0.8177489820156091
# Computing AUC...
# AUC test: 0.8156387852052935
# Computing AUC...
# AUC test: 0.8153736851034951
# Computing AUC...
# AUC test: 0.8166779776043434
# Computing AUC...
# AUC test: 0.817420257889379
# Computing AUC...
# AUC test: 0.8162962334577536
# Computing AUC...
# AUC test: 0.8169960977265015
# BPR with K: 30
# done
# Computing AUC...
# AUC test: 0.49975610790634545
# Computing AUC...
# AUC test: 0.49909865965388533
# Computing AUC...
# AUC test: 0.4991834916864608
# Computing AUC...
# AUC test: 0.4977731591448931
# Computing AUC...
# AUC test: 0.49811248727519514
# Computing AUC...
# AUC test: 0.49899261961316593
# Computing AUC...
# AUC test: 0.5003075161180862
# Computing AUC...
# AUC test: 0.4999045639633526
# Computing AUC...
# AUC test: 0.4969778588394978
# Computing AUC...
# AUC test: 0.5003817441465898
# Computing AUC...
# AUC test: 0.4989502035968782
# Computing AUC...
# AUC test: 0.5002757041058704
# Computing AUC...
# AUC test: 0.5005938242280285
# Computing AUC...
# AUC test: 0.5018026806922293
# Computing AUC...
# AUC test: 0.501198252460129
# Computing AUC...
# AUC test: 0.49893959959280626
# Computing AUC...
# AUC test: 0.4993531557516118
# Computing AUC...
# AUC test: 0.5030857651849339
# Computing AUC...
# AUC test: 0.49739141499830336
# Computing AUC...
# AUC test: 0.5023646929080421
# Computing AUC...
# AUC test: 0.5030751611808619
# Computing AUC...
# AUC test: 0.5040189175432643
# Computing AUC...
# AUC test: 0.5038810654903292
# Computing AUC...
# AUC test: 0.5037644214455378
# Computing AUC...
# AUC test: 0.5049732779097387
# Computing AUC...
# AUC test: 0.5025767729894808
# Computing AUC...
# AUC test: 0.5049838819138106
# Computing AUC...
# AUC test: 0.5092678995588734
# Computing AUC...
# AUC test: 0.510699440108585
# Computing AUC...
# AUC test: 0.5099571598235494
# Computing AUC...
# AUC test: 0.5118552765524262
# Computing AUC...
# AUC test: 0.5126399728537496
# Computing AUC...
# AUC test: 0.5136685612487275
# Computing AUC...
# AUC test: 0.5197128435697319
# Computing AUC...
# AUC test: 0.5217912283678316
# Computing AUC...
# AUC test: 0.5233606209704784
# Computing AUC...
# AUC test: 0.5300199355276553
# Computing AUC...
# AUC test: 0.532448252460129
# Computing AUC...
# AUC test: 0.5381213946386155
# Computing AUC...
# AUC test: 0.542299372242959
# Computing AUC...
# AUC test: 0.5487996267390567
# Computing AUC...
# AUC test: 0.5525958601968103
# Computing AUC...
# AUC test: 0.5601883271123176
# Computing AUC...
# AUC test: 0.5695728707159824
# Computing AUC...
# AUC test: 0.5763912453342382
# Computing AUC...
# AUC test: 0.5834959280624363
# Computing AUC...
# AUC test: 0.5917776552426196
# Computing AUC...
# AUC test: 0.6021801832371904
# Computing AUC...
# AUC test: 0.6086380217170003
# Computing AUC...
# AUC test: 0.6193056498133696
# Computing AUC...
# AUC test: 0.6292628096369189
# Computing AUC...
# AUC test: 0.639272989480828
# Computing AUC...
# AUC test: 0.6517326942653546
# Computing AUC...
# AUC test: 0.6573528164234815
# Computing AUC...
# AUC test: 0.6678189684424839
# Computing AUC...
# AUC test: 0.6771610960298609
# Computing AUC...
# AUC test: 0.6864502035968781
# Computing AUC...
# AUC test: 0.6962483033593485
# Computing AUC...
# AUC test: 0.7051026467594164
# Computing AUC...
# AUC test: 0.714328130302002
# Computing AUC...
# AUC test: 0.7202027485578555
# Computing AUC...
# AUC test: 0.7284526637258228
# Computing AUC...
# AUC test: 0.7361193586698337
# Computing AUC...
# AUC test: 0.7424605531048524
# Computing AUC...
# AUC test: 0.7507210722768918
# Computing AUC...
# AUC test: 0.7548354258568035
# Computing AUC...
# AUC test: 0.7590240074652189
# Computing AUC...
# AUC test: 0.763753393281303
# Computing AUC...
# AUC test: 0.7696492195453003
# Computing AUC...
# AUC test: 0.7748345775364778
# Computing AUC...
# AUC test: 0.7803274516457415
# Computing AUC...
# AUC test: 0.7814514760773669
# Computing AUC...
# AUC test: 0.7841873091279267
# Computing AUC...
# AUC test: 0.7892242110620971
# Computing AUC...
# AUC test: 0.7912601798439091
# Computing AUC...
# AUC test: 0.7945686291143536
# Computing AUC...
# AUC test: 0.7962016457414319
# Computing AUC...
# AUC test: 0.7992980149304377
# Computing AUC...
# AUC test: 0.7999554631828979
# Computing AUC...
# AUC test: 0.8034759925347811
# Computing AUC...
# AUC test: 0.805193841194435
# Computing AUC...
# AUC test: 0.8049287410926366
# Computing AUC...
# AUC test: 0.8062754496097726
# Computing AUC...
# AUC test: 0.809117322701052
# Computing AUC...
# AUC test: 0.8084386664404479
# Computing AUC...
# AUC test: 0.8094142348150661
# Computing AUC...
# AUC test: 0.8104110111978283
# Computing AUC...
# AUC test: 0.8116622836783169
# Computing AUC...
# AUC test: 0.8122030878859857
# Computing AUC...
# AUC test: 0.813348320325755
# Computing AUC...
# AUC test: 0.8116728876823889
# Computing AUC...
# AUC test: 0.8145677807940278
# Computing AUC...
# AUC test: 0.8167416016287751
# Computing AUC...
# AUC test: 0.8154903291482863
# Computing AUC...
# AUC test: 0.8170067017305734
# Computing AUC...
# AUC test: 0.8168900576857822
# Computing AUC...
# AUC test: 0.8169006616898541
# Computing AUC...
# AUC test: 0.8163280454699695
# Computing AUC...
# AUC test: 0.8188517984390906
# Computing AUC...
# AUC test: 0.8177383780115371
# Computing AUC...
# AUC test: 0.8180671021377672
# BPR with K: 30
# done
# Computing AUC...
# AUC test: 0.49975610790634545
# Computing AUC...
# AUC test: 0.5001908720732948
# Computing AUC...
# AUC test: 0.49956523583305057
# Computing AUC...
# AUC test: 0.5000530200203597
# Computing AUC...
# AUC test: 0.500678656260604
# Computing AUC...
# AUC test: 0.5000954360366474
# Computing AUC...
# AUC test: 0.5023116728876824
# Computing AUC...
# AUC test: 0.5015057685782152
# Computing AUC...
# AUC test: 0.49995758398371226
# Computing AUC...
# AUC test: 0.5007422802850356
# Computing AUC...
# AUC test: 0.5016330166270784
# Computing AUC...
# AUC test: 0.4983563793688497
# Computing AUC...
# AUC test: 0.5007104682728198
# Computing AUC...
# AUC test: 0.500349932134374
# Computing AUC...
# AUC test: 0.5026510010179844
# Computing AUC...
# AUC test: 0.501526976586359
# Computing AUC...
# AUC test: 0.5034038853070919
# Computing AUC...
# AUC test: 0.49803825924669154
# Computing AUC...
# AUC test: 0.5010922124194096
# Computing AUC...
# AUC test: 0.5013042925008483
# Computing AUC...
# AUC test: 0.5021844248388191
# Computing AUC...
# AUC test: 0.5028524770953512
# Computing AUC...
# AUC test: 0.49968187987784185
# Computing AUC...
# AUC test: 0.5007316762809637
# Computing AUC...
# AUC test: 0.503223617237869
# Computing AUC...
# AUC test: 0.5017602646759416
# Computing AUC...
# AUC test: 0.5037644214455378
# Computing AUC...
# AUC test: 0.5038174414658976
# Computing AUC...
# AUC test: 0.5058852222599254
# Computing AUC...
# AUC test: 0.5062033423820834
# Computing AUC...
# AUC test: 0.5064790464879538
# Computing AUC...
# AUC test: 0.5035841533763149
# Computing AUC...
# AUC test: 0.5061503223617237
# Computing AUC...
# AUC test: 0.5086316593145572
# Computing AUC...
# AUC test: 0.5057261621988463
# Computing AUC...
# AUC test: 0.5057367662029182
# Computing AUC...
# AUC test: 0.5083453512046149
# Computing AUC...
# AUC test: 0.5106570240922973
# Computing AUC...
# AUC test: 0.5136579572446556
# Computing AUC...
# AUC test: 0.5152379538513743
# Computing AUC...
# AUC test: 0.5162347302341365
# Computing AUC...
# AUC test: 0.5166270783847982
# Computing AUC...
# AUC test: 0.5230000848320325
# Computing AUC...
# AUC test: 0.5267857142857143
# Computing AUC...
# AUC test: 0.5286096029860875
# Computing AUC...
# AUC test: 0.5302426196131659
# Computing AUC...
# AUC test: 0.5334980488632508
# Computing AUC...
# AUC test: 0.537697234475738
# Computing AUC...
# AUC test: 0.5441868849677638
# Computing AUC...
# AUC test: 0.5481633864947404
# Computing AUC...
# AUC test: 0.5530624363759755
# Computing AUC...
# AUC test: 0.5631044282321005
# Computing AUC...
# AUC test: 0.5657766372582287
# Computing AUC...
# AUC test: 0.5729025279945708
# Computing AUC...
# AUC test: 0.5785120461486257
# Computing AUC...
# AUC test: 0.585425856803529
# Computing AUC...
# AUC test: 0.5934742958941296
# Computing AUC...
# AUC test: 0.5990413980318968
# Computing AUC...
# AUC test: 0.606146080760095
# Computing AUC...
# AUC test: 0.6159759925347811
# Computing AUC...
# AUC test: 0.6256256362402444
# Computing AUC...
# AUC test: 0.6326136749236512
# Computing AUC...
# AUC test: 0.6395699015948422
# Computing AUC...
# AUC test: 0.6480425008483204
# Computing AUC...
# AUC test: 0.6595266372582287
# Computing AUC...
# AUC test: 0.6667267560230743
# Computing AUC...
# AUC test: 0.6747751951136749
# Computing AUC...
# AUC test: 0.6846687309127927
# Computing AUC...
# AUC test: 0.6920597217509331
# Computing AUC...
# AUC test: 0.6980615880556498
# Computing AUC...
# AUC test: 0.7067144553783509
# Computing AUC...
# AUC test: 0.7171700033932813
# Computing AUC...
# AUC test: 0.7224614014251781
# Computing AUC...
# AUC test: 0.7285374957583983
# Computing AUC...
# AUC test: 0.7368404309467255
# Computing AUC...
# AUC test: 0.7420045809297591
# Computing AUC...
# AUC test: 0.7487487275195114
# Computing AUC...
# AUC test: 0.7544324737020699
# Computing AUC...
# AUC test: 0.7623536647438073
# Computing AUC...
# AUC test: 0.7636579572446556
# Computing AUC...
# AUC test: 0.7657363420427553
# Computing AUC...
# AUC test: 0.7725653206650831
# Computing AUC...
# AUC test: 0.7786944350186631
# Computing AUC...
# AUC test: 0.7814726840855107
# Computing AUC...
# AUC test: 0.7849083814048184
# Computing AUC...
# AUC test: 0.7876548184594503
# Computing AUC...
# AUC test: 0.7912601798439091
# Computing AUC...
# AUC test: 0.7920872921615202
# Computing AUC...
# AUC test: 0.7941762809636919
# Computing AUC...
# AUC test: 0.8010476756023074
# Computing AUC...
# AUC test: 0.8008355955208687
# Computing AUC...
# AUC test: 0.8006553274516457
# Computing AUC...
# AUC test: 0.803825924669155
# Computing AUC...
# AUC test: 0.8066359857482185
# Computing AUC...
# AUC test: 0.8068162538174415
# Computing AUC...
# AUC test: 0.8094460468272819
# Computing AUC...
# AUC test: 0.8075267220902613
# Computing AUC...
# AUC test: 0.8102413471326773
# Computing AUC...
# AUC test: 0.8130832202239565
# Computing AUC...
# AUC test: 0.8122136918900577
# Computing AUC...
# AUC test: 0.8139845605700713
# BPR with K: 50
# done
# Computing AUC...
# AUC test: 0.5013785205293518
# Computing AUC...
# AUC test: 0.5015057685782152
# Computing AUC...
# AUC test: 0.49997879199185613
# Computing AUC...
# AUC test: 0.501686036647438
# Computing AUC...
# AUC test: 0.5020571767899559
# Computing AUC...
# AUC test: 0.5000636240244316
# Computing AUC...
# AUC test: 0.49823973532405835
# Computing AUC...
# AUC test: 0.5012618764845606
# Computing AUC...
# AUC test: 0.502216236851035
# Computing AUC...
# AUC test: 0.5021420088225313
# Computing AUC...
# AUC test: 0.5031069731930777
# Computing AUC...
# AUC test: 0.5030221411605023
# Computing AUC...
# AUC test: 0.5019193247370207
# Computing AUC...
# AUC test: 0.501876908720733
# Computing AUC...
# AUC test: 0.5006256362402444
# Computing AUC...
# AUC test: 0.5024177129284018
# Computing AUC...
# AUC test: 0.5037114014251781
# Computing AUC...
# AUC test: 0.500678656260604
# Computing AUC...
# AUC test: 0.5042734136409909
# Computing AUC...
# AUC test: 0.5060336783169325
# Computing AUC...
# AUC test: 0.5064366304716661
# Computing AUC...
# AUC test: 0.5031599932134374
# Computing AUC...
# AUC test: 0.508324143196471
# Computing AUC...
# AUC test: 0.5080378350865287
# Computing AUC...
# AUC test: 0.5085362232779097
# Computing AUC...
# AUC test: 0.5108054801493044
# Computing AUC...
# AUC test: 0.5125445368171021
# Computing AUC...
# AUC test: 0.5156090939938921
# Computing AUC...
# AUC test: 0.5162983542585681
# Computing AUC...
# AUC test: 0.5212080081438751
# Computing AUC...
# AUC test: 0.52342424499491
# Computing AUC...
# AUC test: 0.5287262470308789
# Computing AUC...
# AUC test: 0.5325648965049202
# Computing AUC...
# AUC test: 0.536350525958602
# Computing AUC...
# AUC test: 0.5429038004750594
# Computing AUC...
# AUC test: 0.5467424499491008
# Computing AUC...
# AUC test: 0.5554483372921615
# Computing AUC...
# AUC test: 0.5644405327451646
# Computing AUC...
# AUC test: 0.5683428062436376
# Computing AUC...
# AUC test: 0.5794133864947404
# Computing AUC...
# AUC test: 0.5881298778418731
# Computing AUC...
# AUC test: 0.598171869697998
# Computing AUC...
# AUC test: 0.607842721411605
# Computing AUC...
# AUC test: 0.6160608245673567
# Computing AUC...
# AUC test: 0.6272056328469631
# Computing AUC...
# AUC test: 0.6361872242958941
# Computing AUC...
# AUC test: 0.6469608924329827
# Computing AUC...
# AUC test: 0.65625
# Computing AUC...
# AUC test: 0.6674372242958941
# Computing AUC...
# AUC test: 0.6755704954190702
# Computing AUC...
# AUC test: 0.6837885985748219
# Computing AUC...
# AUC test: 0.6921869697997964
# Computing AUC...
# AUC test: 0.7024198337292161
# Computing AUC...
# AUC test: 0.7097790125551409
# Computing AUC...
# AUC test: 0.7170321513403461
# Computing AUC...
# AUC test: 0.7237020699015948
# Computing AUC...
# AUC test: 0.7302129284017645
# Computing AUC...
# AUC test: 0.7380280794027825
# Computing AUC...
# AUC test: 0.7428741092636579
# Computing AUC...
# AUC test: 0.7478473871733967
# Computing AUC...
# AUC test: 0.7549838819138106
# Computing AUC...
# AUC test: 0.7585786392941974
# Computing AUC...
# AUC test: 0.7632231930777061
# Computing AUC...
# AUC test: 0.7657999660671869
# Computing AUC...
# AUC test: 0.769543179504581
# Computing AUC...
# AUC test: 0.7758949779436716
# Computing AUC...
# AUC test: 0.7794791313199865
# Computing AUC...
# AUC test: 0.7816529521547336
# Computing AUC...
# AUC test: 0.78294664065151
# Computing AUC...
# AUC test: 0.7862550899219545
# Computing AUC...
# AUC test: 0.788386494740414
# Computing AUC...
# AUC test: 0.7911965558194775
# Computing AUC...
# AUC test: 0.7942823210044113
# Computing AUC...
# AUC test: 0.7945156090939939
# Computing AUC...
# AUC test: 0.7973150661689854
# Computing AUC...
# AUC test: 0.7994570749915167
# Computing AUC...
# AUC test: 0.7992025788937903
# Computing AUC...
# AUC test: 0.8025004241601629
# Computing AUC...
# AUC test: 0.8005492874109263
# Computing AUC...
# AUC test: 0.8038047166610112
# Computing AUC...
# AUC test: 0.8044091448931117
# Computing AUC...
# AUC test: 0.8063072616219885
# Computing AUC...
# AUC test: 0.8047802850356295
# Computing AUC...
# AUC test: 0.8062754496097726
# Computing AUC...
# AUC test: 0.8083856464200883
# Computing AUC...
# AUC test: 0.8077600101798439
# Computing AUC...
# AUC test: 0.8078130302002036
# Computing AUC...
# AUC test: 0.8106549032914828
# Computing AUC...
# AUC test: 0.8109518154054971
# Computing AUC...
# AUC test: 0.8105488632507635
# Computing AUC...
# AUC test: 0.8122879199185612
# Computing AUC...
# AUC test: 0.8120758398371225
# Computing AUC...
# AUC test: 0.8128605361384459
# Computing AUC...
# AUC test: 0.8135073803868341
# Computing AUC...
# AUC test: 0.8147480488632508
# Computing AUC...
# AUC test: 0.8132104682728198
# Computing AUC...
# AUC test: 0.813857312521208
# Computing AUC...
# AUC test: 0.8149177129284018
# Computing AUC...
# AUC test: 0.8150131489650492
# Computing AUC...
# AUC test: 0.8134013403461147
# Computing AUC...
# AUC test: 0.815044960977265
# BPR with K: 50
# done
# Computing AUC...
# AUC test: 0.5021526128266033
# Computing AUC...
# AUC test: 0.4992683237190363
# Computing AUC...
# AUC test: 0.49889718357651847
# Computing AUC...
# AUC test: 0.5007316762809637
# Computing AUC...
# AUC test: 0.49955463182897863
# Computing AUC...
# AUC test: 0.501187648456057
# Computing AUC...
# AUC test: 0.500339328130302
# Computing AUC...
# AUC test: 0.5003181201221581
# Computing AUC...
# AUC test: 0.5012194604682728
# Computing AUC...
# AUC test: 0.5008059043094673
# Computing AUC...
# AUC test: 0.501876908720733
# Computing AUC...
# AUC test: 0.5049626739056667
# Computing AUC...
# AUC test: 0.5019935527655243
# Computing AUC...
# AUC test: 0.5022268408551069
# Computing AUC...
# AUC test: 0.5033720732948761
# Computing AUC...
# AUC test: 0.5024389209365456
# Computing AUC...
# AUC test: 0.4993531557516118
# Computing AUC...
# AUC test: 0.5016542246352222
# Computing AUC...
# AUC test: 0.5030433491686461
# Computing AUC...
# AUC test: 0.5029373091279267
# Computing AUC...
# AUC test: 0.5034356973193078
# Computing AUC...
# AUC test: 0.505439854088904
# Computing AUC...
# AUC test: 0.5061821343739396
# Computing AUC...
# AUC test: 0.5026828130302002
# Computing AUC...
# AUC test: 0.5078681710213777
# Computing AUC...
# AUC test: 0.5084619952494062
# Computing AUC...
# AUC test: 0.5111978282999661
# Computing AUC...
# AUC test: 0.508334747200543
# Computing AUC...
# AUC test: 0.5117492365117068
# Computing AUC...
# AUC test: 0.5136685612487275
# Computing AUC...
# AUC test: 0.5183025110281643
# Computing AUC...
# AUC test: 0.5196810315575161
# Computing AUC...
# AUC test: 0.5237847811333559
# Computing AUC...
# AUC test: 0.5261070580251103
# Computing AUC...
# AUC test: 0.52785671869698
# Computing AUC...
# AUC test: 0.5314938920936546
# Computing AUC...
# AUC test: 0.5381638106549033
# Computing AUC...
# AUC test: 0.5408042076688158
# Computing AUC...
# AUC test: 0.5455548014930438
# Computing AUC...
# AUC test: 0.5522353240583644
# Computing AUC...
# AUC test: 0.5589794706481167
# Computing AUC...
# AUC test: 0.5666885816084153
# Computing AUC...
# AUC test: 0.5743764845605701
# Computing AUC...
# AUC test: 0.5819901594842213
# Computing AUC...
# AUC test: 0.5894235663386495
# Computing AUC...
# AUC test: 0.599009586019681
# Computing AUC...
# AUC test: 0.6073655412283678
# Computing AUC...
# AUC test: 0.6178316932473702
# Computing AUC...
# AUC test: 0.623653291482864
# Computing AUC...
# AUC test: 0.634342127587377
# Computing AUC...
# AUC test: 0.6451051917203936
# Computing AUC...
# AUC test: 0.653715643026807
# Computing AUC...
# AUC test: 0.6633228707159824
# Computing AUC...
# AUC test: 0.6729831184255175
# Computing AUC...
# AUC test: 0.6822828299966067
# Computing AUC...
# AUC test: 0.6908084492704445
# Computing AUC...
# AUC test: 0.6996627926705123
# Computing AUC...
# AUC test: 0.7067356633864947
# Computing AUC...
# AUC test: 0.7154521547336274
# Computing AUC...
# AUC test: 0.7224932134373939
# Computing AUC...
# AUC test: 0.7269999151679675
# Computing AUC...
# AUC test: 0.7358118425517476
# Computing AUC...
# AUC test: 0.7440087376993553
# Computing AUC...
# AUC test: 0.7489608076009501
# Computing AUC...
# AUC test: 0.7552171700033933
# Computing AUC...
# AUC test: 0.7600631998642687
# Computing AUC...
# AUC test: 0.7631701730573465
# Computing AUC...
# AUC test: 0.7669876145232439
# Computing AUC...
# AUC test: 0.7718972684085511
# Computing AUC...
# AUC test: 0.7754284017645062
# Computing AUC...
# AUC test: 0.7791185951815406
# Computing AUC...
# AUC test: 0.7829784526637258
# Computing AUC...
# AUC test: 0.7853855615880556
# Computing AUC...
# AUC test: 0.788545554801493
# Computing AUC...
# AUC test: 0.7908678316932474
# Computing AUC...
# AUC test: 0.7921721241940957
# Computing AUC...
# AUC test: 0.7962440617577197
# Computing AUC...
# AUC test: 0.7979407024092298
# Computing AUC...
# AUC test: 0.7984815066168985
# Computing AUC...
# AUC test: 0.8010794876145232
# Computing AUC...
# AUC test: 0.8026064642008822
# Computing AUC...
# AUC test: 0.8033063284696301
# Computing AUC...
# AUC test: 0.804515184933831
# Computing AUC...
# AUC test: 0.8064026976586359
# Computing AUC...
# AUC test: 0.808428062436376
# Computing AUC...
# AUC test: 0.8078660502205632
# Computing AUC...
# AUC test: 0.8095308788598575
# Computing AUC...
# AUC test: 0.810304971157109
# Computing AUC...
# AUC test: 0.8110578554462164
# Computing AUC...
# AUC test: 0.8129029521547336
# Computing AUC...
# AUC test: 0.8125
# Computing AUC...
# AUC test: 0.814695028842891
# Computing AUC...
# AUC test: 0.8137300644723447
# Computing AUC...
# AUC test: 0.813857312521208
# Computing AUC...
# AUC test: 0.8172399898201561
# Computing AUC...
# AUC test: 0.8143344927044452
# Computing AUC...
# AUC test: 0.8156387852052935
# Computing AUC...
# AUC test: 0.8163598574821853
# Computing AUC...
# AUC test: 0.8169748897183576
# Computing AUC...
# AUC test: 0.8163386494740414
# Computing AUC...
# AUC test: 0.8177171700033933
# BPR with K: 50
# done
# Computing AUC...
# AUC test: 0.5021101968103155
# Computing AUC...
# AUC test: 0.49930013573125215
# Computing AUC...
# AUC test: 0.4996288598574822
# Computing AUC...
# AUC test: 0.5017814726840855
# Computing AUC...
# AUC test: 0.5004241601628775
# Computing AUC...
# AUC test: 0.5009861723786901
# Computing AUC...
# AUC test: 0.5002438920936546
# Computing AUC...
# AUC test: 0.49968187987784185
# Computing AUC...
# AUC test: 0.4991834916864608
# Computing AUC...
# AUC test: 0.5002014760773669
# Computing AUC...
# AUC test: 0.5001802680692229
# Computing AUC...
# AUC test: 0.5014421445537836
# Computing AUC...
# AUC test: 0.5010179843909061
# Computing AUC...
# AUC test: 0.49873812351543945
# Computing AUC...
# AUC test: 0.49949100780454697
# Computing AUC...
# AUC test: 0.5002226840855107
# Computing AUC...
# AUC test: 0.49975610790634545
# Computing AUC...
# AUC test: 0.5029373091279267
# Computing AUC...
# AUC test: 0.5028524770953512
# Computing AUC...
# AUC test: 0.5006256362402444
# Computing AUC...
# AUC test: 0.5060973023413641
# Computing AUC...
# AUC test: 0.5012936884967764
# Computing AUC...
# AUC test: 0.5037007974211062
# Computing AUC...
# AUC test: 0.5041991856124872
# Computing AUC...
# AUC test: 0.5025661689854088
# Computing AUC...
# AUC test: 0.5034675093315236
# Computing AUC...
# AUC test: 0.5028736851034951
# Computing AUC...
# AUC test: 0.5050793179504581
# Computing AUC...
# AUC test: 0.5056413301662708
# Computing AUC...
# AUC test: 0.5055140821174076
# Computing AUC...
# AUC test: 0.5073379708177808
# Computing AUC...
# AUC test: 0.5081756871394638
# Computing AUC...
# AUC test: 0.5109433322022395
# Computing AUC...
# AUC test: 0.5123006447234476
# Computing AUC...
# AUC test: 0.5107842721411605
# Computing AUC...
# AUC test: 0.5154924499491008
# Computing AUC...
# AUC test: 0.5175602307431286
# Computing AUC...
# AUC test: 0.5189811672887682
# Computing AUC...
# AUC test: 0.5222790125551409
# Computing AUC...
# AUC test: 0.5256616898540889
# Computing AUC...
# AUC test: 0.5274749745503903
# Computing AUC...
# AUC test: 0.5313984560570071
# Computing AUC...
# AUC test: 0.5341979131319986
# Computing AUC...
# AUC test: 0.5384183067526298
# Computing AUC...
# AUC test: 0.5471878181201222
# Computing AUC...
# AUC test: 0.5530200203596878
# Computing AUC...
# AUC test: 0.555363505259586
# Computing AUC...
# AUC test: 0.5583644384119444
# Computing AUC...
# AUC test: 0.5671763657957245
# Computing AUC...
# AUC test: 0.5714391754326433
# Computing AUC...
# AUC test: 0.5774940617577197
# Computing AUC...
# AUC test: 0.5876951136749237
# Computing AUC...
# AUC test: 0.5962207329487614
# Computing AUC...
# AUC test: 0.6027209874448591
# Computing AUC...
# AUC test: 0.6103664743807261
# Computing AUC...
# AUC test: 0.6215961146929081
# Computing AUC...
# AUC test: 0.626866304716661
# Computing AUC...
# AUC test: 0.6360069562266711
# Computing AUC...
# AUC test: 0.645720223956566
# Computing AUC...
# AUC test: 0.6517008822531388
# Computing AUC...
# AUC test: 0.6611596538853071
# Computing AUC...
# AUC test: 0.6703851374278927
# Computing AUC...
# AUC test: 0.6781790804207669
# Computing AUC...
# AUC test: 0.6885922124194096
# Computing AUC...
# AUC test: 0.6933746182558534
# Computing AUC...
# AUC test: 0.700065744825246
# Computing AUC...
# AUC test: 0.7124406175771971
# Computing AUC...
# AUC test: 0.7181773837801154
# Computing AUC...
# AUC test: 0.7239247539871055
# Computing AUC...
# AUC test: 0.7316974889718357
# Computing AUC...
# AUC test: 0.7367980149304377
# Computing AUC...
# AUC test: 0.7442102137767221
# Computing AUC...
# AUC test: 0.748801747539871
# Computing AUC...
# AUC test: 0.7550262979300985
# Computing AUC...
# AUC test: 0.760869104173736
# Computing AUC...
# AUC test: 0.7655348659653886
# Computing AUC...
# AUC test: 0.7704869358669834
# Computing AUC...
# AUC test: 0.7737423651170682
# Computing AUC...
# AUC test: 0.7785883949779436
# Computing AUC...
# AUC test: 0.7817271801832372
# Computing AUC...
# AUC test: 0.7846750933152359
# Computing AUC...
# AUC test: 0.7899028673227011
# Computing AUC...
# AUC test: 0.7911435357991178
# Computing AUC...
# AUC test: 0.792808364438412
# Computing AUC...
# AUC test: 0.7947276891754327
# Computing AUC...
# AUC test: 0.7976437902952155
# Computing AUC...
# AUC test: 0.8009098235493722
# Computing AUC...
# AUC test: 0.8019384119443502
# Computing AUC...
# AUC test: 0.80434552086868
# Computing AUC...
# AUC test: 0.804175856803529
# Computing AUC...
# AUC test: 0.8077175941635562
# Computing AUC...
# AUC test: 0.8073570580251103
# Computing AUC...
# AUC test: 0.8077175941635562
# Computing AUC...
# AUC test: 0.8079402782490669
# Computing AUC...
# AUC test: 0.8101459110960298
# Computing AUC...
# AUC test: 0.8134013403461147
# Computing AUC...
# AUC test: 0.8111002714625043
# Computing AUC...
# AUC test: 0.8149389209365456
# Computing AUC...
# AUC test: 0.8150873769935527
# Computing AUC...
# AUC test: 0.8147056328469631
# Computing AUC...
# AUC test: 0.8166885816084153
# BPR with K: 70
# done
# Computing AUC...
# AUC test: 0.49772013912453344
# Computing AUC...
# AUC test: 0.5006362402443163
# Computing AUC...
# AUC test: 0.4984836274177129
# Computing AUC...
# AUC test: 0.49823973532405835
# Computing AUC...
# AUC test: 0.5011558364438412
# Computing AUC...
# AUC test: 0.4973702069901595
# Computing AUC...
# AUC test: 0.4985260434340007
# Computing AUC...
# AUC test: 0.4993107397353241
# Computing AUC...
# AUC test: 0.49950161180861896
# Computing AUC...
# AUC test: 0.49916228367831694
# Computing AUC...
# AUC test: 0.4988229555480149
# Computing AUC...
# AUC test: 0.5013785205293518
# Computing AUC...
# AUC test: 0.4997136918900577
# Computing AUC...
# AUC test: 0.502035968781812
# Computing AUC...
# AUC test: 0.4989183915846624
# Computing AUC...
# AUC test: 0.4992471157108924
# Computing AUC...
# AUC test: 0.5022692568713947
# Computing AUC...
# AUC test: 0.5007422802850356
# Computing AUC...
# AUC test: 0.5034250933152359
# Computing AUC...
# AUC test: 0.5021208008143875
# Computing AUC...
# AUC test: 0.5022268408551069
# Computing AUC...
# AUC test: 0.5034038853070919
# Computing AUC...
# AUC test: 0.5042840176450628
# Computing AUC...
# AUC test: 0.5044324737020699
# Computing AUC...
# AUC test: 0.5073379708177808
# Computing AUC...
# AUC test: 0.5080060230743129
# Computing AUC...
# AUC test: 0.5091300475059383
# Computing AUC...
# AUC test: 0.5123324567356634
# Computing AUC...
# AUC test: 0.5141881574482524
# Computing AUC...
# AUC test: 0.5183767390566678
# Computing AUC...
# AUC test: 0.5218972684085511
# Computing AUC...
# AUC test: 0.5246861214794707
# Computing AUC...
# AUC test: 0.5316741601628775
# Computing AUC...
# AUC test: 0.5365626060400407
# Computing AUC...
# AUC test: 0.5439005768578216
# Computing AUC...
# AUC test: 0.5486829826942654
# Computing AUC...
# AUC test: 0.5560739735324058
# Computing AUC...
# AUC test: 0.5639633525619274
# Computing AUC...
# AUC test: 0.5723193077706142
# Computing AUC...
# AUC test: 0.5785650661689854
# Computing AUC...
# AUC test: 0.5865286732270105
# Computing AUC...
# AUC test: 0.5970796572785884
# Computing AUC...
# AUC test: 0.6070686291143536
# Computing AUC...
# AUC test: 0.6155412283678316
# Computing AUC...
# AUC test: 0.6239077875805904
# Computing AUC...
# AUC test: 0.6361342042755345
# Computing AUC...
# AUC test: 0.6464731082456736
# Computing AUC...
# AUC test: 0.6532702748557856
# Computing AUC...
# AUC test: 0.6621776382762131
# Computing AUC...
# AUC test: 0.6716258059043094
# Computing AUC...
# AUC test: 0.6808300814387512
# Computing AUC...
# AUC test: 0.6895041567695962
# Computing AUC...
# AUC test: 0.6975950118764845
# Computing AUC...
# AUC test: 0.707043179504581
# Computing AUC...
# AUC test: 0.713999406175772
# Computing AUC...
# AUC test: 0.7188030200203597
# Computing AUC...
# AUC test: 0.7249957583983713
# Computing AUC...
# AUC test: 0.7312521208008144
# Computing AUC...
# AUC test: 0.7396823040380047
# Computing AUC...
# AUC test: 0.7433194774346793
# Computing AUC...
# AUC test: 0.751357312521208
# Computing AUC...
# AUC test: 0.7549732779097387
# Computing AUC...
# AUC test: 0.758334747200543
# Computing AUC...
# AUC test: 0.7617598405157787
# Computing AUC...
# AUC test: 0.7656833220223956
# Computing AUC...
# AUC test: 0.7693417034272141
# Computing AUC...
# AUC test: 0.7753965897522904
# Computing AUC...
# AUC test: 0.7765842382083474
# Computing AUC...
# AUC test: 0.7780687987784187
# Computing AUC...
# AUC test: 0.7820240922972514
# Computing AUC...
# AUC test: 0.7845690532745164
# Computing AUC...
# AUC test: 0.7848765693926026
# Computing AUC...
# AUC test: 0.7895211231761113
# Computing AUC...
# AUC test: 0.7906345436036647
# Computing AUC...
# AUC test: 0.7903376314896505
# Computing AUC...
# AUC test: 0.7945474211062097
# Computing AUC...
# AUC test: 0.7944307770614184
# Computing AUC...
# AUC test: 0.7978558703766542
# Computing AUC...
# AUC test: 0.7996055310485239
# Computing AUC...
# AUC test: 0.7988950627757041
# Computing AUC...
# AUC test: 0.8007613674923652
# Computing AUC...
# AUC test: 0.8012703596878181
# Computing AUC...
# AUC test: 0.8045469969460468
# Computing AUC...
# AUC test: 0.8056498133695283
# Computing AUC...
# AUC test: 0.8057346454021038
# Computing AUC...
# AUC test: 0.8045045809297591
# Computing AUC...
# AUC test: 0.8061694095690533
# Computing AUC...
# AUC test: 0.8082796063793688
# Computing AUC...
# AUC test: 0.807049541907024
# Computing AUC...
# AUC test: 0.809276382762131
# Computing AUC...
# AUC test: 0.8106018832711231
# Computing AUC...
# AUC test: 0.8106124872751951
# Computing AUC...
# AUC test: 0.8113971835765185
# Computing AUC...
# AUC test: 0.809615710892433
# Computing AUC...
# AUC test: 0.8109942314217848
# Computing AUC...
# AUC test: 0.8098808109942314
# Computing AUC...
# AUC test: 0.8123197319307771
# Computing AUC...
# AUC test: 0.8114608076009501
# Computing AUC...
# AUC test: 0.8110048354258568
# Computing AUC...
# AUC test: 0.8120864438411944
# Computing AUC...
# AUC test: 0.8134649643705463
# BPR with K: 70
# done
# Computing AUC...
# AUC test: 0.5015163725822871
# Computing AUC...
# AUC test: 0.49786859518154053
# Computing AUC...
# AUC test: 0.49975610790634545
# Computing AUC...
# AUC test: 0.49823973532405835
# Computing AUC...
# AUC test: 0.49712631489650494
# Computing AUC...
# AUC test: 0.49888657957244653
# Computing AUC...
# AUC test: 0.49925771971496435
# Computing AUC...
# AUC test: 0.5020571767899559
# Computing AUC...
# AUC test: 0.5030857651849339
# Computing AUC...
# AUC test: 0.5008801323379708
# Computing AUC...
# AUC test: 0.5005832202239565
# Computing AUC...
# AUC test: 0.5005726162198846
# Computing AUC...
# AUC test: 0.5025555649813369
# Computing AUC...
# AUC test: 0.4993531557516118
# Computing AUC...
# AUC test: 0.5008271123176111
# Computing AUC...
# AUC test: 0.4982609433322022
# Computing AUC...
# AUC test: 0.5024601289446895
# Computing AUC...
# AUC test: 0.5032766372582287
# Computing AUC...
# AUC test: 0.5035523413640991
# Computing AUC...
# AUC test: 0.5021738208347472
# Computing AUC...
# AUC test: 0.5043264336613505
# Computing AUC...
# AUC test: 0.5029903291482863
# Computing AUC...
# AUC test: 0.5033402612826603
# Computing AUC...
# AUC test: 0.5051641499830336
# Computing AUC...
# AUC test: 0.5041567695961995
# Computing AUC...
# AUC test: 0.504750593824228
# Computing AUC...
# AUC test: 0.5051429419748897
# Computing AUC...
# AUC test: 0.5070198506956227
# Computing AUC...
# AUC test: 0.5081862911435358
# Computing AUC...
# AUC test: 0.51017984390906
# Computing AUC...
# AUC test: 0.510699440108585
# Computing AUC...
# AUC test: 0.5165952663725822
# Computing AUC...
# AUC test: 0.5164362063115032
# Computing AUC...
# AUC test: 0.5202324397692569
# Computing AUC...
# AUC test: 0.5208156599932134
# Computing AUC...
# AUC test: 0.5248133695283339
# Computing AUC...
# AUC test: 0.5276128266033254
# Computing AUC...
# AUC test: 0.5345266372582287
# Computing AUC...
# AUC test: 0.5373366983372921
# Computing AUC...
# AUC test: 0.541960044112657
# Computing AUC...
# AUC test: 0.5513445877163217
# Computing AUC...
# AUC test: 0.5531048523922634
# Computing AUC...
# AUC test: 0.5604110111978283
# Computing AUC...
# AUC test: 0.5682049541907024
# Computing AUC...
# AUC test: 0.5735069562266711
# Computing AUC...
# AUC test: 0.583559552086868
# Computing AUC...
# AUC test: 0.5885116219884629
# Computing AUC...
# AUC test: 0.5994973702069901
# Computing AUC...
# AUC test: 0.6070156090939939
# Computing AUC...
# AUC test: 0.6132189514760774
# Computing AUC...
# AUC test: 0.6255620122158126
# Computing AUC...
# AUC test: 0.6347662877502545
# Computing AUC...
# AUC test: 0.6452430437733289
# Computing AUC...
# AUC test: 0.6545745673566339
# Computing AUC...
# AUC test: 0.6616686460807601
# Computing AUC...
# AUC test: 0.673566338649474
# Computing AUC...
# AUC test: 0.6797166610111979
# Computing AUC...
# AUC test: 0.6905963691890058
# Computing AUC...
# AUC test: 0.6953999830335935
# Computing AUC...
# AUC test: 0.7059297590770275
# Computing AUC...
# AUC test: 0.7149961825585341
# Computing AUC...
# AUC test: 0.7187924160162877
# Computing AUC...
# AUC test: 0.7271271632168307
# Computing AUC...
# AUC test: 0.7344015100101798
# Computing AUC...
# AUC test: 0.7379220393620631
# Computing AUC...
# AUC test: 0.7456311503223617
# Computing AUC...
# AUC test: 0.751187648456057
# Computing AUC...
# AUC test: 0.7557049541907024
# Computing AUC...
# AUC test: 0.7595223956566
# Computing AUC...
# AUC test: 0.765471241940957
# Computing AUC...
# AUC test: 0.7692992874109263
# Computing AUC...
# AUC test: 0.7721623685103495
# Computing AUC...
# AUC test: 0.7753753817441466
# Computing AUC...
# AUC test: 0.7799987275195114
# Computing AUC...
# AUC test: 0.781939260264676
# Computing AUC...
# AUC test: 0.7863081099423143
# Computing AUC...
# AUC test: 0.7859157617916526
# Computing AUC...
# AUC test: 0.7899983033593485
# Computing AUC...
# AUC test: 0.791779776043434
# Computing AUC...
# AUC test: 0.7924478282999661
# Computing AUC...
# AUC test: 0.7965091618595181
# Computing AUC...
# AUC test: 0.7989586868001357
# Computing AUC...
# AUC test: 0.7989904988123515
# Computing AUC...
# AUC test: 0.8002947913131999
# Computing AUC...
# AUC test: 0.8022565320665083
# Computing AUC...
# AUC test: 0.803507804546997
# Computing AUC...
# AUC test: 0.8044621649134713
# Computing AUC...
# AUC test: 0.8049711571089243
# Computing AUC...
# AUC test: 0.8058406854428232
# Computing AUC...
# AUC test: 0.80877799457075
# Computing AUC...
# AUC test: 0.809265778758059
# Computing AUC...
# AUC test: 0.8070389379029521
# Computing AUC...
# AUC test: 0.8089688666440448
# Computing AUC...
# AUC test: 0.8124257719714965
# Computing AUC...
# AUC test: 0.8120440278249067
# Computing AUC...
# AUC test: 0.8122561079063454
# Computing AUC...
# AUC test: 0.8148010688836105
# Computing AUC...
# AUC test: 0.8143026806922293
# Computing AUC...
# AUC test: 0.8140799966067187
# Computing AUC...
# AUC test: 0.8149071089243298
# Computing AUC...
# AUC test: 0.8156175771971497
# BPR with K: 70
# done
# Computing AUC...
# AUC test: 0.5022904648795385
# Computing AUC...
# AUC test: 0.5000848320325755
# Computing AUC...
# AUC test: 0.5019405327451646
# Computing AUC...
# AUC test: 0.4981973193077706
# Computing AUC...
# AUC test: 0.49952281981676283
# Computing AUC...
# AUC test: 0.4994061757719715
# Computing AUC...
# AUC test: 0.5030963691890058
# Computing AUC...
# AUC test: 0.5010073803868341
# Computing AUC...
# AUC test: 0.4991198676620292
# Computing AUC...
# AUC test: 0.499151679674245
# Computing AUC...
# AUC test: 0.49956523583305057
# Computing AUC...
# AUC test: 0.4993743637597557
# Computing AUC...
# AUC test: 0.5013997285374957
# Computing AUC...
# AUC test: 0.4986851034950797
# Computing AUC...
# AUC test: 0.5014845605700713
# Computing AUC...
# AUC test: 0.501198252460129
# Computing AUC...
# AUC test: 0.50306455717679
# Computing AUC...
# AUC test: 0.5023116728876824
# Computing AUC...
# AUC test: 0.5028630810994231
# Computing AUC...
# AUC test: 0.5012300644723447
# Computing AUC...
# AUC test: 0.502884289107567
# Computing AUC...
# AUC test: 0.500848320325755
# Computing AUC...
# AUC test: 0.5051111299626739
# Computing AUC...
# AUC test: 0.5035311333559552
# Computing AUC...
# AUC test: 0.5056943501866304
# Computing AUC...
# AUC test: 0.5035205293518833
# Computing AUC...
# AUC test: 0.5018238887003733
# Computing AUC...
# AUC test: 0.5026828130302002
# Computing AUC...
# AUC test: 0.5047399898201561
# Computing AUC...
# AUC test: 0.5071683067526298
# Computing AUC...
# AUC test: 0.5071683067526298
# Computing AUC...
# AUC test: 0.5085150152697658
# Computing AUC...
# AUC test: 0.50645783847981
# Computing AUC...
# AUC test: 0.5059170342721412
# Computing AUC...
# AUC test: 0.5124703087885986
# Computing AUC...
# AUC test: 0.517496606718697
# Computing AUC...
# AUC test: 0.5167013064133017
# Computing AUC...
# AUC test: 0.5177192908042076
# Computing AUC...
# AUC test: 0.5207944519850696
# Computing AUC...
# AUC test: 0.5241665252799457
# Computing AUC...
# AUC test: 0.5253329657278588
# Computing AUC...
# AUC test: 0.5285565829657278
# Computing AUC...
# AUC test: 0.5331481167288769
# Computing AUC...
# AUC test: 0.5372200542925009
# Computing AUC...
# AUC test: 0.5432537326094333
# Computing AUC...
# AUC test: 0.5479937224295894
# Computing AUC...
# AUC test: 0.5529033763148965
# Computing AUC...
# AUC test: 0.5576645741431965
# Computing AUC...
# AUC test: 0.5636770444519851
# Computing AUC...
# AUC test: 0.5689048184594503
# Computing AUC...
# AUC test: 0.5768366135052596
# Computing AUC...
# AUC test: 0.5852137767220903
# Computing AUC...
# AUC test: 0.5929334916864608
# Computing AUC...
# AUC test: 0.5998048863250763
# Computing AUC...
# AUC test: 0.6085001696640652
# Computing AUC...
# AUC test: 0.6180967933491687
# Computing AUC...
# AUC test: 0.6259225483542585
# Computing AUC...
# AUC test: 0.6348193077706142
# Computing AUC...
# AUC test: 0.6433343230403801
# Computing AUC...
# AUC test: 0.6514251781472684
# Computing AUC...
# AUC test: 0.659812945368171
# Computing AUC...
# AUC test: 0.6678931964709874
# Computing AUC...
# AUC test: 0.6770762639972854
# Computing AUC...
# AUC test: 0.6836931625381744
# Computing AUC...
# AUC test: 0.6939790464879538
# Computing AUC...
# AUC test: 0.7026743298269427
# Computing AUC...
# AUC test: 0.710086528673227
# Computing AUC...
# AUC test: 0.7167776552426196
# Computing AUC...
# AUC test: 0.7234157617916526
# Computing AUC...
# AUC test: 0.7315702409229725
# Computing AUC...
# AUC test: 0.7381553274516457
# Computing AUC...
# AUC test: 0.7428847132677299
# Computing AUC...
# AUC test: 0.7471263148965049
# Computing AUC...
# AUC test: 0.7520889888021717
# Computing AUC...
# AUC test: 0.7590876314896505
# Computing AUC...
# AUC test: 0.7668497624703088
# Computing AUC...
# AUC test: 0.7680480149304377
# Computing AUC...
# AUC test: 0.7734878690193417
# Computing AUC...
# AUC test: 0.7754602137767221
# Computing AUC...
# AUC test: 0.7813136240244316
# Computing AUC...
# AUC test: 0.7844948252460129
# Computing AUC...
# AUC test: 0.7871246182558534
# Computing AUC...
# AUC test: 0.7905391075670173
# Computing AUC...
# AUC test: 0.791270783847981
# Computing AUC...
# AUC test: 0.7938263488293179
# Computing AUC...
# AUC test: 0.7984178825924669
# Computing AUC...
# AUC test: 0.7980467424499491
# Computing AUC...
# AUC test: 0.800602307431286
# Computing AUC...
# AUC test: 0.8033805564981337
# Computing AUC...
# AUC test: 0.8032214964370546
# Computing AUC...
# AUC test: 0.8072086019681032
# Computing AUC...
# AUC test: 0.8049393450967085
# Computing AUC...
# AUC test: 0.8071131659314558
# Computing AUC...
# AUC test: 0.8115244316253818
# Computing AUC...
# AUC test: 0.8112805395317272
# Computing AUC...
# AUC test: 0.8114183915846623
# Computing AUC...
# AUC test: 0.8124151679674245
# Computing AUC...
# AUC test: 0.8117789277231082
# Computing AUC...
# AUC test: 0.8147692568713947
# Computing AUC...
# AUC test: 0.8152676450627757
# Computing AUC...
# AUC test: 0.8143875127248049

# %%
i = 0
for k in ks:
    j = 0
    for _lambda in lambdas:
        print("With k = " + str(k) + " and lambda = " + ('%.3f' % _lambda) + ": AUC = " + ('%.6f' % results[i][j][1]) )
        j+=1
    i+=1
# Out:
# With k = 30 and lambda = 0.010: AUC = 0.816996
# With k = 30 and lambda = 0.025: AUC = 0.818067
# With k = 30 and lambda = 0.050: AUC = 0.813985
# With k = 50 and lambda = 0.010: AUC = 0.815045
# With k = 50 and lambda = 0.025: AUC = 0.817717
# With k = 50 and lambda = 0.050: AUC = 0.816689
# With k = 70 and lambda = 0.010: AUC = 0.813465
# With k = 70 and lambda = 0.025: AUC = 0.815618
# With k = 70 and lambda = 0.050: AUC = 0.814388

# %%
'''
failsDict = {
    "BiasNormal": list(map(lambda x: [int(x[0]), int(x[1])], normalfails)),
    "NoBiasNormal": list(map(lambda x: [int(x[0]), int(x[1])], nobiasnormalfails)),
    "NoBias075": list(map(lambda x: [int(x[0]), int(x[1])], nobiasnormal_0_75_fails)),
    "NoBias0875": list(map(lambda x: [int(x[0]), int(x[1])], nobiasnormal_0_875_fails)),
    "Dummy": list(map(lambda x: [int(x[0]), int(x[1])], failsDummy)),
}

with open("data/fails.json", "w") as out:
    json.dump(failsDict, out)
'''
with open("data/fails.json", "r") as in_file:
    failsDict = json.load(in_file)

# %% [markdown]
# ## Analysis of accuracy according to recipes popularity

# %%
dfNoBias = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), failsDict["NoBiasNormal"])))
dfBias = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), failsDict["BiasNormal"])))
dfNoBias0875 = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), failsDict["NoBias0875"])))
dfNoBias075 = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), failsDict["NoBias075"])))
dfDummy = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), failsDict["Dummy"])))

allInteractions = pd.DataFrame(list(map(lambda x: len(recipeUsers[x[0]]), interactions_te)))

# %%
with sns.plotting_context("notebook", font_scale=2):
    compareFails(allInteractions, [dfDummy, dfBias, dfNoBias, dfNoBias0875, dfNoBias075], ["Popularity Ranker", "With Bias", "No Bias", "Power 0.875", "Power 0.75"])

# %% [markdown]
# ## Cross validation

# %%
'''

aucs = []
lambdas = np.linspace(0.007, 0.013, 10)
for _lambda in lambdas:
    for k in [20, 30, 50, 80]:
        auc = BPR(interactions_tr, interactions_te, False, P=uFactorsSimple, Q=rFactorsSimple, alpha=0.05, _lambda=_lambda, K=k, prob=False, _pop=False, _iter = 50*10**6)[1]
        aucs.append(auc)
        print("AUC with K=" + str(k) + " lambda=" + str(_lambda) + ": " + str(auc))
'''
# Out:
# '\n\naucs = []\nlambdas = np.linspace(0.007, 0.013, 10)\nfor _lambda in lambdas:\n    for k in [20, 30, 50, 80]:\n        auc = BPR(interactions_tr, interactions_te, False, P=uFactorsSimple, Q=rFactorsSimple, alpha=0.05, _lambda=_lambda, K=k, prob=False, _pop=False, _iter = 50*10**6)[1]\n        aucs.append(auc)\n        print("AUC with K=" + str(k) + " lambda=" + str(_lambda) + ": " + str(auc))\n'

# %% [markdown]
# ## Dummy Ranker
#
# Evaluating the performance of a dummy ranker in order to compare it to the performance of our model. The dummy ranker simply rank recipes according to the number of reviews they have.

# %%
len(recipes)
# Out:
# 26980

# %%
print("Computing AUC of dummy ranker...")
# Compute the Area Under the Curve (AUC)
auc = 0;
failsDummy = []
for interaction in interactions_te:
    recipe = interaction[0]
    user = interaction[1]
    n_recipe = sample_neg(recipes, user, userRecipes)

    sp = len(recipeUsers_tr[recipe])
    sn = len(recipeUsers_tr[n_recipe])

    if sp > sn:
        auc = auc+1
    else:
        failsDummy.append((recipe, n_recipe))
        if sp == sn:
            auc = auc+0.5

auc = auc / len(interactions_te)
print("AUC test: " + str(auc))
# Out:
# Computing AUC of dummy ranker...
# AUC test: 0.838985746620175
